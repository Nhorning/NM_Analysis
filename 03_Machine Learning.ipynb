# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Time series analysis - predict levels of violence based on previous weeks.
# We will attempt to predict levels of violence for upcoming weeks based on data from previous weeks. The production of this data could potentially be automated with a script and displayed on the Nepal Monitor platform alongside current data. Any predictions would likely need to have interpretable metrics and be displayed with a confidence score for purposes of accountability

# %% [markdown]
# ### Data Preparation:

# %%
#list available files in directory
print('Raw Files:')
! ls Data
print('\nProcessed Files:')
! ls Data/output/
# Out:
# Raw Files:
# 1519759656_39328483.csv
# 2017 PMP Data Final No Duplicates.xlsx
# Federal_VDC_Relation_web_clean.xlsx
# Federal_VDC_Relation_web.xlsx
# nepalmonitor-reports.csv
# nepalmonitor-reports_old.csv
# nepal_population_household_ward-2011.csv
# NM_2016_17export.csv
# npl_polbanda_adm5_wad_25k_50k_sdn_wgs84.csv
# output
#
# Processed Files:
# District_Province_Population	 NM_2017-18_timeshift
# NM_2016_17clean.csv		 NM_2017-18_timeshift_province
# NM_2017-18_onehot_day		 pop_incidents_VDC.csv
# NM_2017-18_onehot_week		 sources_vdc.csv
# NM_2017-18_onehot_week_province

# %%
#import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

#set up a custom qualitative color palette
xkcd_colors = ['purple','green','blue','pink','brown','red','light blue',\
              'tan','light green','magenta','yellow','sky blue','teal','orange','light purple']
catpal = sns.xkcd_palette(xkcd_colors)


#Import Primary Data Frames
cleanpath='Data/output/NM_2016_17clean.csv'#clean 2017 dataset
newpath = 'Data/nepalmonitor-reports.csv'#NM latest export - new site version
df = pd.read_csv(cleanpath)
new_df = pd.read_csv(newpath)

print(df.shape[0],'x',df.shape[1])
print(new_df.shape[0], 'x',new_df.shape[1])
# Out:
# 6630 x 68
# 7203 x 55

# %% [markdown]
# Previous data cleaning efforts have focused on export data, from the previous Nepal Monitor platform. As of November 2018 a new version of NepalMonitor has been deployed, with a significantly streamlined export file. Machine Learning will focus on this new file format (new_df).

# %%
#convert 'INCIDENT DATE' column to date time objects
    
new_df.loc[:,'Event Date'] = pd.to_datetime(new_df.loc[:,'Event Date'])
new_df.index = pd.to_datetime(new_df.loc[:,'Event Date'])
#new_df = new_df.loc['2017':'2018',:]# < taken out to have part of the 2017 data

print(df.shape)
print(new_df.shape)
new_df.head()
# Out:
# (6630, 68)
# (7203, 55)
#                 #                                     Title  \
# Event Date
# 2018-12-31  21793         Complaint registered against rape
# 2018-12-31  21803      Man held on charge of attempted rape
# 2018-12-31  21804  Agitating civil servants take to streets
# 2018-12-31  21810         Complaint registered against rape
# 2018-12-30  21779       Police arrests youth on rape charge
#
#                                              Nepali Title Event Date  \
# Event Date
# 2018-12-31  चकलेट दिन्छु भन्दै ५ बर्षीया बालिका बलात्कार। 2018-12-31
# 2018-12-31       बलात्कार प्रयास घटनाका आरोपित गिरफ्तार । 2018-12-31
# 2018-12-31  समायोजनविरुद्ध सडकमै उत्रिए निजामती कर्मचारी। 2018-12-31
# 2018-12-31     बलात्कार घटनाका आरोपितविरूद्ध उजुरी दर्ता। 2018-12-31
# 2018-12-30          जवरजस्ती करणी गरेको अभियोगमा पक्राउ । 2018-12-30
#
#            Publication Date                                 Location  \
# Event Date
# 2018-12-31       2018-12-31         Province 2, Parsa, Pakahamainpur
# 2018-12-31       2019-01-01  Province 1, Morang, Biratnagar, Ward 10
# 2018-12-31       2019-01-01                    Province 3, Kathmandu
# 2018-12-31       2019-01-02                        Province 2, Parsa
# 2018-12-30       2018-12-30    Province 5, Rukum East, Bhume, Ward 2
#
#                                                   Description  \
# Event Date
# 2018-12-31  A complaint against 19 years old Dev Kumar Pat...
# 2018-12-31  Police have arrested 25 years old Gyanendra Sa...
# 2018-12-31  Agitating civil servants today took to the str...
# 2018-12-31  A complaint against 19 years old Dev Kumar Pat...
# 2018-12-30  Police on Sunday arrested 22-year-old Laxman B...
#
#                                            Nepali Description  \
# Event Date
# 2018-12-31  पर्साको पकहामैनपुर गाउँपालिका १ मा धोरेमा ५ बर...
# 2018-12-31  १८ वर्षीया युवतीलाई बलात्कार प्रयास गरेको आरोप...
# 2018-12-31  कर्मचारी समायोजन अध्यादेशको विरोधमा निजामती कर...
# 2018-12-31  पाँच वर्षीया बालिकालाई बलात्कार गरेको आरोपमा प...
# 2018-12-30  पुथाउत्तरगंगा गाउँपालिका-१२ घर भई भूमे गाउँपाल...
#
#                               Tags            Latitude  \
# Event Date
# 2018-12-31  GBV\nChildren’s Rights   27.03046158726636
# 2018-12-31                     GBV  26.454562034856874
# 2018-12-31              Governance    27.7058766168406
# 2018-12-31  GBV\nChildren’s Rights  27.173588000000002
# 2018-12-30  GBV\nChildren’s Rights  28.545244075518408
#
#                           ...                 Youth raped Total abducted  \
# Event Date                ...
# 2018-12-31                ...                         1.0            0.0
# 2018-12-31                ...                         1.0            0.0
# 2018-12-31                ...                         NaN            NaN
# 2018-12-31                ...                         1.0            0.0
# 2018-12-30                ...                         1.0            0.0
#
#            Female abducted Youth abducted Total damaged buildings  \
# Event Date
# 2018-12-31             0.0            0.0                     0.0
# 2018-12-31             0.0            0.0                     0.0
# 2018-12-31             NaN            NaN                     NaN
# 2018-12-31             0.0            0.0                     0.0
# 2018-12-30             0.0            0.0                     0.0
#
#            Severely damaged buildings Total damaged vehicles  \
# Event Date
# 2018-12-31                        0.0                    0.0
# 2018-12-31                        0.0                    0.0
# 2018-12-31                        NaN                    NaN
# 2018-12-31                        0.0                    0.0
# 2018-12-30                        0.0                    0.0
#
#            Severely damaged vehicles Election-related cause - primary  \
# Event Date
# 2018-12-31                       0.0                              NaN
# 2018-12-31                       0.0                              NaN
# 2018-12-31                       NaN                              NaN
# 2018-12-31                       0.0                              NaN
# 2018-12-30                       0.0                              NaN
#
#            Election-related cause - secondary
# Event Date
# 2018-12-31                                NaN
# 2018-12-31                                NaN
# 2018-12-31                                NaN
# 2018-12-31                                NaN
# 2018-12-30                                NaN
#
# [5 rows x 55 columns]

# %%
#Drop out unneeded columns - leaving in provinces doesn't seem to break anything
new_drop = ['#','Title','Nepali Title', 'Ward','Publication Date','Event Date',
            'Nepali Description','Tags','Location','Latitude','Longitude']

test_df = new_df.dropna(axis=1, how='all')#.sort_index(axis=1)

test_df.drop(new_drop, axis=1, inplace=True)

# %%
#Fix minor inconsistencies in export file variables to facilitate dummy columns creation

#Some cells include the same cateogry name repeated on a new line. Strip out the second line.
def strip_newline(string):
    if type(string) == str:
        return string.split('\n')[0]#.lower().replace('nonviolent', 'non-violent').strip()
    else:
        return string

#Strip out anything contained in () and make everything lowercase
def strip_paren(string):
    if type(string) == str:
        return string.split('(')[0].lower()#.replace('nonviolent', 'non-violent').replace('noyouth', 'no-youth').strip()
    else:
        return string

#train_df = train_df.applymap(strip_paren)
full_df = test_df.applymap(strip_newline).applymap(strip_paren)

#train_df.append(test_df) < it looks like the variables are coded differently let's just use 1 dataset for now
full_df.loc[:,'Total killed'] = (full_df.loc[:,'Total killed'] == '1').astype(int)

# %%
#One-hot encode categorical columns
dummies = ['Violent / Nonviolent', 'Onesided / Twosided', 'Collective / Interpersonal', 'Event Form - Primary', 'Event Form - Secondary', 'Weapons', 'Cause - Primary', 'Cause - Secondary', 'Actor 1 - Affiliation', 'Actor 1 - Entity', 'Actor 1 - Youth/non-youth', 'Actor 2 - Target', 'Actor 2 - Affiliation','Actor 2 - Youth/non-youth']

incidents_date_test = pd.get_dummies(full_df, columns=dummies, dummy_na=False)

#strip out blank dummy categories 
for col in dummies:
    badstr = col+'_'
    if badstr in incidents_date_test.columns:
        incidents_date.drop(badstr, inplace=True, axis=1)
        print('dropped useless category:', badstr)
    
#aggrigate into weekly and daily dataframes
in_week = incidents_date_test.resample('W').sum()
in_day = incidents_date_test.resample('D').sum()

#Create weekly aggrigations by province
in_week_province = incidents_date_test.groupby('Province').resample('W').sum()

#Export data-frames CSV for opensource analysis
in_week.to_csv('Data/output/NM_2017-18_onehot_week')
in_day.to_csv('Data/output/NM_2017-18_onehot_day')
in_week_province.to_csv('Data/output/NM_2017-18_onehot_week_province')

print(in_week_province.shape)
#print(in_day_province.shape)
in_week_province.loc[('province 3',),:].head()
# Out:
# (737, 321)
#             Total killed  Female killed  Youth killed  Total injured  \
# Event Date
# 2017-01-01           0.0            0.0           0.0            0.0
# 2017-01-08           2.0            0.0           0.0            2.0
# 2017-01-15           2.0            0.0           1.0            4.0
# 2017-01-22           1.0            0.0           0.0           33.0
# 2017-01-29           3.0            1.0           2.0           18.0
#
#             Female injured  Total raped  Female raped  Youth raped  \
# Event Date
# 2017-01-01             0.0          0.0           0.0          0.0
# 2017-01-08             1.0          0.0           0.0          0.0
# 2017-01-15             3.0          2.0           2.0          2.0
# 2017-01-22             1.0          1.0           1.0          1.0
# 2017-01-29             1.0          1.0           1.0          1.0
#
#             Total abducted  Female abducted               ...                 \
# Event Date                                                ...
# 2017-01-01             0.0              0.0               ...
# 2017-01-08             0.0              0.0               ...
# 2017-01-15             1.0              0.0               ...
# 2017-01-22             0.0              0.0               ...
# 2017-01-29             0.0              0.0               ...
#
#             Actor 2 - Affiliation_security forces - apf  \
# Event Date
# 2017-01-01                                          0.0
# 2017-01-08                                          0.0
# 2017-01-15                                          0.0
# 2017-01-22                                          0.0
# 2017-01-29                                          0.0
#
#             Actor 2 - Affiliation_security forces - army  \
# Event Date
# 2017-01-01                                           0.0
# 2017-01-08                                           0.0
# 2017-01-15                                           0.0
# 2017-01-22                                           0.0
# 2017-01-29                                           0.0
#
#             Actor 2 - Affiliation_security forces - police  \
# Event Date
# 2017-01-01                                             0.0
# 2017-01-08                                             1.0
# 2017-01-15                                             0.0
# 2017-01-22                                             2.0
# 2017-01-29                                             1.0
#
#             Actor 2 - Affiliation_security forces - security forces   \
# Event Date
# 2017-01-01                                                0.0
# 2017-01-08                                                0.0
# 2017-01-15                                                0.0
# 2017-01-22                                                0.0
# 2017-01-29                                                0.0
#
#             Actor 2 - Affiliation_students  Actor 2 - Affiliation_unclear  \
# Event Date
# 2017-01-01                             0.0                            0.0
# 2017-01-08                             0.0                            0.0
# 2017-01-15                             0.0                            0.0
# 2017-01-22                             0.0                            0.0
# 2017-01-29                             0.0                            0.0
#
#             Actor 2 - Youth/non-youth_na  Actor 2 - Youth/non-youth_noyouth  \
# Event Date
# 2017-01-01                           1.0                                0.0
# 2017-01-08                           4.0                                2.0
# 2017-01-15                           3.0                                3.0
# 2017-01-22                           7.0                                1.0
# 2017-01-29                           4.0                                3.0
#
#             Actor 2 - Youth/non-youth_unknown  Actor 2 - Youth/non-youth_youth
# Event Date
# 2017-01-01                                0.0                              0.0
# 2017-01-08                                2.0                              1.0
# 2017-01-15                                1.0                              5.0
# 2017-01-22                                3.0                              1.0
# 2017-01-29                                1.0                              3.0
#
# [5 rows x 321 columns]

# %% [markdown]
# Above, we have created a separate column for each variable tracked by the project, and given it a 1 if it was marked and a 0 if not (one hot encoding) and aggregated them by day and week, we have also created a separate data frame grouped by province for province-wise analysis, and saved all these data frames to CSV, so others interested in using the data can grab it directly in those formats

# %%
#feature engineering: adding known events like elections into dataset
def dc(m,d):
    return dt.datetime(2017,m,d)

def electon(date,dtdict):
    for key in dtdict.keys():
        if dtdict[key][0] <= date <= dtdict[key][1]:
            return 1
    return 0
    
def addelections(df):
    '''add elections as feature to dataset'''
#create dictionary of election date-times
    dtdict = {}
    #begin = dc(2,20)
    #end = dc(5,1)
    #dtdict['Local Registration'] = [begin,end]
    begin = dc(5,7)
    end = dc(5,14)
    dtdict['1st Local'] = [begin,end]
    
    begin = dc(6,21)
    end = dc(6,28)
    dtdict['2nd Local'] = [begin,end]
    
    begin = dc(9,11)
    end = dc(9,18)
    dtdict['3rd local'] = [begin,end]
    
    begin = dc(11,19)
    end = dc(11,26)
    dtdict['1st Provincial'] = [begin, end]
    
    begin = dc(11,30)
    end = dc(12,7)
    dtdict['2nd Provincial'] = [begin, end]
    
    begin = dt.datetime(2018,3,6)
    end = dt.datetime(2018,3,13)
    dtdict['Presidential'] = [begin, end]
    
    #add a column to the df called election, set it to 1 if it's in the dates in the dtdict
    #well make in the second column so it doesn't through other functions off
    df.insert(1, 'Election_on', [electon(x,dtdict) for x in df.index])
    
    return df

for df in [in_week, in_day]:
    df = addelections(df)

in_week
# Out:
#             Total killed  Election_on  Female killed  Youth killed  \
# Event Date
# 2017-01-01             2            0            3.0           3.0
# 2017-01-08             9            0            5.0           5.0
# 2017-01-15            11            0            4.0           3.0
# 2017-01-22             4            0            1.0           1.0
# 2017-01-29             8            0            1.0           5.0
# 2017-02-05            10            0            7.0           5.0
# 2017-02-12            10            0            6.0           5.0
# 2017-02-19             5            0            2.0           2.0
# 2017-02-26             7            0            5.0           5.0
# 2017-03-05            10            0            6.0           4.0
# 2017-03-12             8            0            2.0           2.0
# 2017-03-19             9            0            4.0           5.0
# 2017-03-26             9            0            5.0           6.0
# 2017-04-02            12            0            4.0           6.0
# 2017-04-09             5            0            0.0           0.0
# 2017-04-16             7            0            2.0           1.0
# 2017-04-23             6            0            4.0           2.0
# 2017-04-30             3            0            2.0           3.0
# 2017-05-07             8            1            4.0           3.0
# 2017-05-14            11            1            0.0           0.0
# 2017-05-21             3            0            3.0           2.0
# 2017-05-28             3            0            1.0           1.0
# 2017-06-04             4            0            4.0           3.0
# 2017-06-11            12            0            3.0           5.0
# 2017-06-18             7            0            2.0           2.0
# 2017-06-25            10            1            8.0           9.0
# 2017-07-02             4            0            1.0           1.0
# 2017-07-09             6            0            4.0           2.0
# 2017-07-16             7            0            5.0           2.0
# 2017-07-23            10            0            7.0           7.0
# ...                  ...          ...            ...           ...
# 2018-06-17            11            0            7.0           7.0
# 2018-06-24            10            0            7.0           6.0
# 2018-07-01            13            0            5.0           4.0
# 2018-07-08             7            0            4.0           2.0
# 2018-07-15            11            0            9.0           7.0
# 2018-07-22             8            0            4.0           2.0
# 2018-07-29             6            0            3.0           4.0
# 2018-08-05            12            0            3.0           7.0
# 2018-08-12             2            0            2.0           2.0
# 2018-08-19             4            0            4.0           5.0
# 2018-08-26            12            0            6.0           6.0
# 2018-09-02             3            0            3.0           3.0
# 2018-09-09             7            0            5.0           3.0
# 2018-09-16            10            0            6.0           5.0
# 2018-09-23             9            0            4.0           4.0
# 2018-09-30             8            0            5.0           4.0
# 2018-10-07             1            0            0.0           1.0
# 2018-10-14             5            0            3.0           3.0
# 2018-10-21             5            0            3.0           2.0
# 2018-10-28             4            0            4.0           1.0
# 2018-11-04             4            0            1.0           0.0
# 2018-11-11             8            0            4.0           1.0
# 2018-11-18             2            0            1.0           1.0
# 2018-11-25             6            0            3.0           1.0
# 2018-12-02             3            0            1.0           1.0
# 2018-12-09             4            0            2.0           2.0
# 2018-12-16             3            0            0.0           3.0
# 2018-12-23             4            0            1.0           2.0
# 2018-12-30             4            0            1.0           2.0
# 2019-01-06             0            0            0.0           0.0
#
#             Total injured  Female injured  Total raped  Female raped  \
# Event Date
# 2017-01-01            8.0             4.0          1.0           1.0
# 2017-01-08           20.0             2.0          7.0           7.0
# 2017-01-15           10.0             4.0          6.0           6.0
# 2017-01-22           62.0             5.0          5.0           5.0
# 2017-01-29           34.0             3.0         10.0          10.0
# 2017-02-05           20.0             0.0          5.0           5.0
# 2017-02-12           59.0             4.0          8.0           8.0
# 2017-02-19           25.0             4.0          7.0           7.0
# 2017-02-26           39.0             1.0         10.0          10.0
# 2017-03-05          108.0             5.0         11.0          11.0
# 2017-03-12           32.0             9.0          7.0           7.0
# 2017-03-19           31.0             3.0         10.0          10.0
# 2017-03-26           43.0             3.0          5.0           5.0
# 2017-04-02           21.0             3.0         11.0          11.0
# 2017-04-09           26.0             1.0          3.0           3.0
# 2017-04-16           43.0             3.0          6.0           6.0
# 2017-04-23           16.0             0.0          9.0           9.0
# 2017-04-30           41.0             9.0          9.0           9.0
# 2017-05-07           67.0             3.0          9.0           9.0
# 2017-05-14          109.0             5.0          6.0           6.0
# 2017-05-21           68.0             1.0          7.0           7.0
# 2017-05-28            9.0             3.0          6.0           6.0
# 2017-06-04           19.0             4.0         13.0          13.0
# 2017-06-11           32.0             6.0          8.0           8.0
# 2017-06-18          108.0             7.0          7.0           7.0
# 2017-06-25           68.0             7.0          4.0           4.0
# 2017-07-02           60.0             0.0         10.0          10.0
# 2017-07-09           19.0             6.0         14.0          14.0
# 2017-07-16           19.0             4.0         13.0          13.0
# 2017-07-23           39.0             8.0         18.0          18.0
# ...                   ...             ...          ...           ...
# 2018-06-17           60.0             8.0         19.0          13.0
# 2018-06-24           11.0             1.0          9.0           9.0
# 2018-07-01           13.0             3.0          9.0           9.0
# 2018-07-08            8.0             3.0         17.0          17.0
# 2018-07-15           27.0             9.0         20.0          20.0
# 2018-07-22           64.0             5.0         26.0          25.0
# 2018-07-29           38.0             3.0         16.0          16.0
# 2018-08-05           10.0             2.0         25.0          25.0
# 2018-08-12            5.0             2.0         14.0          13.0
# 2018-08-19            8.0             0.0         16.0          16.0
# 2018-08-26           32.0             7.0         26.0          18.0
# 2018-09-02            8.0             7.0         22.0          22.0
# 2018-09-09            4.0             1.0         10.0          10.0
# 2018-09-16           19.0             6.0         23.0          23.0
# 2018-09-23           12.0             2.0         15.0          15.0
# 2018-09-30           10.0             4.0         26.0          26.0
# 2018-10-07            7.0             2.0         21.0          21.0
# 2018-10-14            2.0             1.0         12.0          12.0
# 2018-10-21            2.0             1.0          2.0           2.0
# 2018-10-28            8.0             1.0         14.0          14.0
# 2018-11-04           19.0             6.0          4.0           4.0
# 2018-11-11           30.0             2.0         20.0          20.0
# 2018-11-18           14.0             6.0         10.0          10.0
# 2018-11-25           12.0             0.0          9.0           9.0
# 2018-12-02            2.0             1.0          9.0           9.0
# 2018-12-09            4.0             0.0         11.0          11.0
# 2018-12-16            3.0             1.0         17.0          17.0
# 2018-12-23            7.0             1.0         14.0          14.0
# 2018-12-30           16.0             3.0         14.0          14.0
# 2019-01-06            0.0             0.0          3.0           3.0
#
#             Youth raped  Total abducted               ...                 \
# Event Date                                            ...
# 2017-01-01          1.0             0.0               ...
# 2017-01-08          6.0             0.0               ...
# 2017-01-15          6.0             1.0               ...
# 2017-01-22          3.0             1.0               ...
# 2017-01-29          7.0             1.0               ...
# 2017-02-05          3.0             0.0               ...
# 2017-02-12          8.0             1.0               ...
# 2017-02-19          6.0             3.0               ...
# 2017-02-26          9.0             0.0               ...
# 2017-03-05         10.0             1.0               ...
# 2017-03-12          6.0             1.0               ...
# 2017-03-19          9.0             0.0               ...
# 2017-03-26          3.0             0.0               ...
# 2017-04-02          8.0             1.0               ...
# 2017-04-09          3.0             2.0               ...
# 2017-04-16          6.0             3.0               ...
# 2017-04-23          6.0             2.0               ...
# 2017-04-30          9.0             0.0               ...
# 2017-05-07          8.0             4.0               ...
# 2017-05-14          4.0             2.0               ...
# 2017-05-21          4.0             0.0               ...
# 2017-05-28          6.0             0.0               ...
# 2017-06-04          9.0             1.0               ...
# 2017-06-11          6.0             2.0               ...
# 2017-06-18          7.0             1.0               ...
# 2017-06-25          3.0             2.0               ...
# 2017-07-02         10.0             0.0               ...
# 2017-07-09          9.0             0.0               ...
# 2017-07-16         12.0             1.0               ...
# 2017-07-23         18.0             1.0               ...
# ...                 ...             ...               ...
# 2018-06-17         16.0             1.0               ...
# 2018-06-24          6.0             1.0               ...
# 2018-07-01          5.0             0.0               ...
# 2018-07-08         15.0             0.0               ...
# 2018-07-15         14.0             1.0               ...
# 2018-07-22         21.0             2.0               ...
# 2018-07-29         12.0             0.0               ...
# 2018-08-05         21.0             6.0               ...
# 2018-08-12         10.0             0.0               ...
# 2018-08-19         13.0             0.0               ...
# 2018-08-26         23.0             0.0               ...
# 2018-09-02         20.0             0.0               ...
# 2018-09-09         10.0             2.0               ...
# 2018-09-16         19.0             1.0               ...
# 2018-09-23         11.0             0.0               ...
# 2018-09-30         22.0             1.0               ...
# 2018-10-07         15.0             0.0               ...
# 2018-10-14         12.0             0.0               ...
# 2018-10-21          2.0             0.0               ...
# 2018-10-28         11.0             1.0               ...
# 2018-11-04          3.0             1.0               ...
# 2018-11-11         17.0             0.0               ...
# 2018-11-18          9.0             0.0               ...
# 2018-11-25          8.0             0.0               ...
# 2018-12-02          6.0             0.0               ...
# 2018-12-09         11.0             1.0               ...
# 2018-12-16         14.0             0.0               ...
# 2018-12-23          9.0             0.0               ...
# 2018-12-30         14.0             0.0               ...
# 2019-01-06          3.0             0.0               ...
#
#             Actor 2 - Affiliation_security forces - apf  \
# Event Date
# 2017-01-01                                            0
# 2017-01-08                                            0
# 2017-01-15                                            0
# 2017-01-22                                            0
# 2017-01-29                                            0
# 2017-02-05                                            0
# 2017-02-12                                            0
# 2017-02-19                                            0
# 2017-02-26                                            0
# 2017-03-05                                            0
# 2017-03-12                                            0
# 2017-03-19                                            0
# 2017-03-26                                            0
# 2017-04-02                                            0
# 2017-04-09                                            0
# 2017-04-16                                            0
# 2017-04-23                                            0
# 2017-04-30                                            0
# 2017-05-07                                            0
# 2017-05-14                                            0
# 2017-05-21                                            0
# 2017-05-28                                            0
# 2017-06-04                                            0
# 2017-06-11                                            0
# 2017-06-18                                            0
# 2017-06-25                                            0
# 2017-07-02                                            0
# 2017-07-09                                            0
# 2017-07-16                                            0
# 2017-07-23                                            0
# ...                                                 ...
# 2018-06-17                                            0
# 2018-06-24                                            0
# 2018-07-01                                            0
# 2018-07-08                                            0
# 2018-07-15                                            0
# 2018-07-22                                            0
# 2018-07-29                                            2
# 2018-08-05                                            0
# 2018-08-12                                            0
# 2018-08-19                                            0
# 2018-08-26                                            0
# 2018-09-02                                            0
# 2018-09-09                                            0
# 2018-09-16                                            0
# 2018-09-23                                            0
# 2018-09-30                                            0
# 2018-10-07                                            0
# 2018-10-14                                            0
# 2018-10-21                                            0
# 2018-10-28                                            0
# 2018-11-04                                            0
# 2018-11-11                                            0
# 2018-11-18                                            0
# 2018-11-25                                            0
# 2018-12-02                                            0
# 2018-12-09                                            0
# 2018-12-16                                            0
# 2018-12-23                                            0
# 2018-12-30                                            0
# 2019-01-06                                            0
#
#             Actor 2 - Affiliation_security forces - army  \
# Event Date
# 2017-01-01                                             0
# 2017-01-08                                             0
# 2017-01-15                                             0
# 2017-01-22                                             0
# 2017-01-29                                             0
# 2017-02-05                                             0
# 2017-02-12                                             0
# 2017-02-19                                             0
# 2017-02-26                                             0
# 2017-03-05                                             0
# 2017-03-12                                             0
# 2017-03-19                                             0
# 2017-03-26                                             0
# 2017-04-02                                             0
# 2017-04-09                                             0
# 2017-04-16                                             0
# 2017-04-23                                             0
# 2017-04-30                                             0
# 2017-05-07                                             0
# 2017-05-14                                             0
# 2017-05-21                                             0
# 2017-05-28                                             0
# 2017-06-04                                             0
# 2017-06-11                                             0
# 2017-06-18                                             0
# 2017-06-25                                             0
# 2017-07-02                                             0
# 2017-07-09                                             0
# 2017-07-16                                             0
# 2017-07-23                                             0
# ...                                                  ...
# 2018-06-17                                             0
# 2018-06-24                                             0
# 2018-07-01                                             0
# 2018-07-08                                             0
# 2018-07-15                                             0
# 2018-07-22                                             0
# 2018-07-29                                             0
# 2018-08-05                                             0
# 2018-08-12                                             0
# 2018-08-19                                             0
# 2018-08-26                                             0
# 2018-09-02                                             0
# 2018-09-09                                             0
# 2018-09-16                                             0
# 2018-09-23                                             0
# 2018-09-30                                             0
# 2018-10-07                                             0
# 2018-10-14                                             0
# 2018-10-21                                             0
# 2018-10-28                                             0
# 2018-11-04                                             0
# 2018-11-11                                             0
# 2018-11-18                                             0
# 2018-11-25                                             0
# 2018-12-02                                             0
# 2018-12-09                                             0
# 2018-12-16                                             0
# 2018-12-23                                             0
# 2018-12-30                                             0
# 2019-01-06                                             0
#
#             Actor 2 - Affiliation_security forces - police  \
# Event Date
# 2017-01-01                                               0
# 2017-01-08                                               2
# 2017-01-15                                               0
# 2017-01-22                                               2
# 2017-01-29                                               1
# 2017-02-05                                               1
# 2017-02-12                                               2
# 2017-02-19                                               4
# 2017-02-26                                               4
# 2017-03-05                                               1
# 2017-03-12                                               2
# 2017-03-19                                               0
# 2017-03-26                                               2
# 2017-04-02                                               2
# 2017-04-09                                               2
# 2017-04-16                                               1
# 2017-04-23                                               3
# 2017-04-30                                               6
# 2017-05-07                                               0
# 2017-05-14                                               3
# 2017-05-21                                               1
# 2017-05-28                                               1
# 2017-06-04                                               2
# 2017-06-11                                               2
# 2017-06-18                                               6
# 2017-06-25                                               0
# 2017-07-02                                               1
# 2017-07-09                                               0
# 2017-07-16                                               1
# 2017-07-23                                               0
# ...                                                    ...
# 2018-06-17                                               6
# 2018-06-24                                               1
# 2018-07-01                                               1
# 2018-07-08                                               1
# 2018-07-15                                               1
# 2018-07-22                                               2
# 2018-07-29                                               1
# 2018-08-05                                               2
# 2018-08-12                                               0
# 2018-08-19                                               0
# 2018-08-26                                               4
# 2018-09-02                                               0
# 2018-09-09                                               0
# 2018-09-16                                               1
# 2018-09-23                                               1
# 2018-09-30                                               0
# 2018-10-07                                               0
# 2018-10-14                                               0
# 2018-10-21                                               0
# 2018-10-28                                               0
# 2018-11-04                                               1
# 2018-11-11                                               0
# 2018-11-18                                               0
# 2018-11-25                                               1
# 2018-12-02                                               0
# 2018-12-09                                               2
# 2018-12-16                                               0
# 2018-12-23                                               2
# 2018-12-30                                               1
# 2019-01-06                                               0
#
#             Actor 2 - Affiliation_security forces - security forces   \
# Event Date
# 2017-01-01                                                  0
# 2017-01-08                                                  0
# 2017-01-15                                                  0
# 2017-01-22                                                  0
# 2017-01-29                                                  0
# 2017-02-05                                                  0
# 2017-02-12                                                  0
# 2017-02-19                                                  0
# 2017-02-26                                                  0
# 2017-03-05                                                  0
# 2017-03-12                                                  0
# 2017-03-19                                                  0
# 2017-03-26                                                  0
# 2017-04-02                                                  0
# 2017-04-09                                                  0
# 2017-04-16                                                  0
# 2017-04-23                                                  0
# 2017-04-30                                                  0
# 2017-05-07                                                  0
# 2017-05-14                                                  0
# 2017-05-21                                                  0
# 2017-05-28                                                  0
# 2017-06-04                                                  0
# 2017-06-11                                                  0
# 2017-06-18                                                  0
# 2017-06-25                                                  0
# 2017-07-02                                                  0
# 2017-07-09                                                  0
# 2017-07-16                                                  0
# 2017-07-23                                                  0
# ...                                                       ...
# 2018-06-17                                                  0
# 2018-06-24                                                  0
# 2018-07-01                                                  0
# 2018-07-08                                                  0
# 2018-07-15                                                  0
# 2018-07-22                                                  0
# 2018-07-29                                                  0
# 2018-08-05                                                  0
# 2018-08-12                                                  0
# 2018-08-19                                                  0
# 2018-08-26                                                  0
# 2018-09-02                                                  0
# 2018-09-09                                                  0
# 2018-09-16                                                  0
# 2018-09-23                                                  0
# 2018-09-30                                                  0
# 2018-10-07                                                  0
# 2018-10-14                                                  0
# 2018-10-21                                                  0
# 2018-10-28                                                  0
# 2018-11-04                                                  0
# 2018-11-11                                                  0
# 2018-11-18                                                  0
# 2018-11-25                                                  0
# 2018-12-02                                                  0
# 2018-12-09                                                  0
# 2018-12-16                                                  0
# 2018-12-23                                                  0
# 2018-12-30                                                  0
# 2019-01-06                                                  0
#
#             Actor 2 - Affiliation_students  Actor 2 - Affiliation_unclear  \
# Event Date
# 2017-01-01                               0                              0
# 2017-01-08                               0                              0
# 2017-01-15                               0                              0
# 2017-01-22                               0                              0
# 2017-01-29                               0                              0
# 2017-02-05                               0                              0
# 2017-02-12                               0                              0
# 2017-02-19                               0                              0
# 2017-02-26                               0                              0
# 2017-03-05                               1                              0
# 2017-03-12                               0                              0
# 2017-03-19                               0                              0
# 2017-03-26                               0                              0
# 2017-04-02                               0                              0
# 2017-04-09                               0                              0
# 2017-04-16                               0                              0
# 2017-04-23                               1                              0
# 2017-04-30                               0                              0
# 2017-05-07                               0                              0
# 2017-05-14                               0                              0
# 2017-05-21                               0                              0
# 2017-05-28                               0                              0
# 2017-06-04                               0                              0
# 2017-06-11                               0                              0
# 2017-06-18                               0                              0
# 2017-06-25                               0                              0
# 2017-07-02                               0                              0
# 2017-07-09                               0                              0
# 2017-07-16                               0                              0
# 2017-07-23                               0                              0
# ...                                    ...                            ...
# 2018-06-17                               0                              0
# 2018-06-24                               0                              0
# 2018-07-01                               0                              0
# 2018-07-08                               0                              0
# 2018-07-15                               0                              0
# 2018-07-22                               0                              0
# 2018-07-29                               0                              0
# 2018-08-05                               0                              0
# 2018-08-12                               0                              0
# 2018-08-19                               0                              0
# 2018-08-26                               0                              0
# 2018-09-02                               0                              0
# 2018-09-09                               0                              0
# 2018-09-16                               0                              0
# 2018-09-23                               0                              0
# 2018-09-30                               0                              0
# 2018-10-07                               0                              0
# 2018-10-14                               0                              0
# 2018-10-21                               0                              0
# 2018-10-28                               0                              0
# 2018-11-04                               0                              0
# 2018-11-11                               0                              0
# 2018-11-18                               1                              0
# 2018-11-25                               0                              0
# 2018-12-02                               0                              0
# 2018-12-09                               0                              0
# 2018-12-16                               0                              0
# 2018-12-23                               0                              0
# 2018-12-30                               0                              0
# 2019-01-06                               0                              0
#
#             Actor 2 - Youth/non-youth_na  Actor 2 - Youth/non-youth_noyouth  \
# Event Date
# 2017-01-01                             4                                  1
# 2017-01-08                            28                                  9
# 2017-01-15                            20                                 10
# 2017-01-22                            28                                  6
# 2017-01-29                            19                                 11
# 2017-02-05                            35                                 13
# 2017-02-12                            28                                 14
# 2017-02-19                            24                                  8
# 2017-02-26                            24                                  3
# 2017-03-05                            23                                 12
# 2017-03-12                            52                                 11
# 2017-03-19                            49                                  6
# 2017-03-26                            34                                  7
# 2017-04-02                            32                                 13
# 2017-04-09                            24                                  8
# 2017-04-16                            26                                 12
# 2017-04-23                            32                                  7
# 2017-04-30                            35                                  2
# 2017-05-07                            41                                 16
# 2017-05-14                            66                                 19
# 2017-05-21                            25                                  9
# 2017-05-28                            26                                  6
# 2017-06-04                            30                                 18
# 2017-06-11                            35                                 15
# 2017-06-18                            71                                 13
# 2017-06-25                            27                                 22
# 2017-07-02                            84                                 18
# 2017-07-09                            13                                 19
# 2017-07-16                            21                                 13
# 2017-07-23                            15                                 12
# ...                                  ...                                ...
# 2018-06-17                            25                                 18
# 2018-06-24                            11                                 12
# 2018-07-01                            23                                 14
# 2018-07-08                            17                                 10
# 2018-07-15                            29                                 16
# 2018-07-22                            31                                 18
# 2018-07-29                            15                                 10
# 2018-08-05                            15                                 12
# 2018-08-12                             8                                  9
# 2018-08-19                            22                                  7
# 2018-08-26                            13                                 10
# 2018-09-02                            10                                  6
# 2018-09-09                             5                                  8
# 2018-09-16                             4                                 14
# 2018-09-23                            11                                  9
# 2018-09-30                            15                                 11
# 2018-10-07                            16                                 10
# 2018-10-14                             4                                  5
# 2018-10-21                             0                                  6
# 2018-10-28                             1                                 12
# 2018-11-04                             4                                 11
# 2018-11-11                             4                                 10
# 2018-11-18                             3                                  5
# 2018-11-25                             3                                  7
# 2018-12-02                             5                                  8
# 2018-12-09                             7                                  4
# 2018-12-16                             8                                  7
# 2018-12-23                            10                                 10
# 2018-12-30                             2                                  5
# 2019-01-06                             1                                  0
#
#             Actor 2 - Youth/non-youth_unknown  Actor 2 - Youth/non-youth_youth
# Event Date
# 2017-01-01                                  2                                4
# 2017-01-08                                  8                               14
# 2017-01-15                                  7                               16
# 2017-01-22                                 14                                6
# 2017-01-29                                 14                               15
# 2017-02-05                                  5                               11
# 2017-02-12                                 13                               15
# 2017-02-19                                 10                               12
# 2017-02-26                                 12                               22
# 2017-03-05                                  8                               28
# 2017-03-12                                 18                               16
# 2017-03-19                                 12                               23
# 2017-03-26                                 12                               16
# 2017-04-02                                 12                               21
# 2017-04-09                                  6                                8
# 2017-04-16                                  8                               12
# 2017-04-23                                 13                               12
# 2017-04-30                                  7                               17
# 2017-05-07                                 23                               15
# 2017-05-14                                 74                                7
# 2017-05-21                                 14                               12
# 2017-05-28                                  6                               11
# 2017-06-04                                  9                               15
# 2017-06-11                                 12                               17
# 2017-06-18                                 31                               13
# 2017-06-25                                 16                               10
# 2017-07-02                                 23                               13
# 2017-07-09                                  8                               15
# 2017-07-16                                  8                               17
# 2017-07-23                                  9                               27
# ...                                       ...                              ...
# 2018-06-17                                 14                               25
# 2018-06-24                                  6                               15
# 2018-07-01                                  6                               14
# 2018-07-08                                  5                               20
# 2018-07-15                                  9                               24
# 2018-07-22                                 11                               28
# 2018-07-29                                 11                               16
# 2018-08-05                                  7                               28
# 2018-08-12                                  5                               13
# 2018-08-19                                  2                               21
# 2018-08-26                                  4                               26
# 2018-09-02                                  3                               22
# 2018-09-09                                  2                               14
# 2018-09-16                                  2                               26
# 2018-09-23                                  3                               24
# 2018-09-30                                  2                               29
# 2018-10-07                                  3                               20
# 2018-10-14                                  0                               15
# 2018-10-21                                  1                                5
# 2018-10-28                                  3                               12
# 2018-11-04                                  5                                5
# 2018-11-11                                  5                               14
# 2018-11-18                                  2                               18
# 2018-11-25                                  3                                9
# 2018-12-02                                  0                               11
# 2018-12-09                                  3                               15
# 2018-12-16                                  0                               15
# 2018-12-23                                  5                               14
# 2018-12-30                                  2                               22
# 2019-01-06                                  0                                3
#
# [106 rows x 322 columns]

# %%
#function for converting pandas time series dataframe to training set for supervised learning
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
        Returns:
        Pandas DataFrame of series framed for supervised learning.
        https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s(t-%03d)' % (df.columns[j], i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s(t)' % (df.columns[j])) for j in range(n_vars)]
        else:
            names += [('%s(t+%03d)' % (df.columns[j], i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
#Create a time shifted dataframe of all variables.
def make_timeshift(df, lookback):
    time_shift = series_to_supervised(df, lookback, dropnan=False).fillna(0)
    return time_shift

lookback=1
time_shift_week = make_timeshift(in_week, lookback)
time_shift_day = make_timeshift(in_day, lookback)
time_shift_province = make_timeshift(in_week_province, lookback)
print(time_shift_day.shape)
print(time_shift_week.shape)
test = pd.concat([time_shift_week['Total killed(t-001)'],time_shift_week['Total killed(t)']],axis=1)
print(test[:5])
#Save this for posterity
time_shift_week.to_csv('Data/output/NM_2017-18_timeshift')
time_shift_week.to_csv('Data/output/NM_2017-18_timeshift_province')

time_shift_week.head()
# Out:
# (730, 644)
# (106, 644)
#             Total killed(t-001)  Total killed(t)
# Event Date
# 2017-01-01                  0.0                2
# 2017-01-08                  2.0                9
# 2017-01-15                  9.0               11
# 2017-01-22                 11.0                4
# 2017-01-29                  4.0                8
#             Total killed(t-001)  Election_on(t-001)  Female killed(t-001)  \
# Event Date
# 2017-01-01                  0.0                 0.0                   0.0
# 2017-01-08                  2.0                 0.0                   3.0
# 2017-01-15                  9.0                 0.0                   5.0
# 2017-01-22                 11.0                 0.0                   4.0
# 2017-01-29                  4.0                 0.0                   1.0
#
#             Youth killed(t-001)  Total injured(t-001)  Female injured(t-001)  \
# Event Date
# 2017-01-01                  0.0                   0.0                    0.0
# 2017-01-08                  3.0                   8.0                    4.0
# 2017-01-15                  5.0                  20.0                    2.0
# 2017-01-22                  3.0                  10.0                    4.0
# 2017-01-29                  1.0                  62.0                    5.0
#
#             Total raped(t-001)  Female raped(t-001)  Youth raped(t-001)  \
# Event Date
# 2017-01-01                 0.0                  0.0                 0.0
# 2017-01-08                 1.0                  1.0                 1.0
# 2017-01-15                 7.0                  7.0                 6.0
# 2017-01-22                 6.0                  6.0                 6.0
# 2017-01-29                 5.0                  5.0                 3.0
#
#             Total abducted(t-001)                 ...                  \
# Event Date                                        ...
# 2017-01-01                    0.0                 ...
# 2017-01-08                    0.0                 ...
# 2017-01-15                    0.0                 ...
# 2017-01-22                    1.0                 ...
# 2017-01-29                    1.0                 ...
#
#             Actor 2 - Affiliation_security forces - apf(t)  \
# Event Date
# 2017-01-01                                               0
# 2017-01-08                                               0
# 2017-01-15                                               0
# 2017-01-22                                               0
# 2017-01-29                                               0
#
#             Actor 2 - Affiliation_security forces - army(t)  \
# Event Date
# 2017-01-01                                                0
# 2017-01-08                                                0
# 2017-01-15                                                0
# 2017-01-22                                                0
# 2017-01-29                                                0
#
#             Actor 2 - Affiliation_security forces - police(t)  \
# Event Date
# 2017-01-01                                                  0
# 2017-01-08                                                  2
# 2017-01-15                                                  0
# 2017-01-22                                                  2
# 2017-01-29                                                  1
#
#             Actor 2 - Affiliation_security forces - security forces (t)  \
# Event Date
# 2017-01-01                                                  0
# 2017-01-08                                                  0
# 2017-01-15                                                  0
# 2017-01-22                                                  0
# 2017-01-29                                                  0
#
#             Actor 2 - Affiliation_students(t)  \
# Event Date
# 2017-01-01                                  0
# 2017-01-08                                  0
# 2017-01-15                                  0
# 2017-01-22                                  0
# 2017-01-29                                  0
#
#             Actor 2 - Affiliation_unclear(t)  Actor 2 - Youth/non-youth_na(t)  \
# Event Date
# 2017-01-01                                 0                                4
# 2017-01-08                                 0                               28
# 2017-01-15                                 0                               20
# 2017-01-22                                 0                               28
# 2017-01-29                                 0                               19
#
#             Actor 2 - Youth/non-youth_noyouth(t)  \
# Event Date
# 2017-01-01                                     1
# 2017-01-08                                     9
# 2017-01-15                                    10
# 2017-01-22                                     6
# 2017-01-29                                    11
#
#             Actor 2 - Youth/non-youth_unknown(t)  \
# Event Date
# 2017-01-01                                     2
# 2017-01-08                                     8
# 2017-01-15                                     7
# 2017-01-22                                    14
# 2017-01-29                                    14
#
#             Actor 2 - Youth/non-youth_youth(t)
# Event Date
# 2017-01-01                                   4
# 2017-01-08                                  14
# 2017-01-15                                  16
# 2017-01-22                                   6
# 2017-01-29                                  15
#
# [5 rows x 644 columns]

# %% [markdown]
# The functions above take the aggregated data and "time shift" it so that can be used for supervised learning. It essentially puts a series of weeks on the same row as a given number of previous weeks represented by the "lookback" variable. The previous weeks will be used as input and the subsequent weeks will be used to train and score predictions based on that output. Again we have saved this data to CSV so others can grab it directly for analysis.
#
# Next we will create the X and y sets needed to to train the models, as well as a holdout set that the models will not "see" during training.

# %%
#Create X y - with holdhout split 
def create_X_y(df, holdpc=.25):
    '''function to create X y for training and holdout sets'''
    holdsize = int(holdpc * len(df.index))
    y = df.loc[:,'Total killed(t)':]#.iloc[:-holdsize,:]
    X = df.loc[:,:'Actor 2 - Youth/non-youth_youth(t-001)']#.iloc[:-holdsize,:]
    
    holdout_y = df.loc[:,'Total killed(t)':].iloc[-holdsize:,:]
    holdout_X = df.loc[:,:'Actor 2 - Youth/non-youth_youth(t-001)'].iloc[-holdsize:,:]

    return X, y, holdout_X, holdout_y

#create X_y for daily aggrigation
X_day, y_day, holdout_X_day, holdout_y_day = create_X_y(time_shift_day)

#create X_y for weekly aggrigation
X_week, y_week, holdout_X_week, holdout_y_week = create_X_y(time_shift_week)

#create X_y for weekly aggrigation by province
X_province, y_province, holdout_X_province, holdout_y_province = create_X_y(time_shift_province)

#print out shapes of datasets for sanity checking
for x in [X_day, y_day, holdout_X_day, holdout_y_day, X_week, y_week, holdout_X_week, holdout_y_week]:
    print(x.shape)

#output last 5 rows of y_province to show its stucture
y_province.tail()
# Out:
# (730, 322)
# (730, 322)
# (182, 322)
# (182, 322)
# (106, 322)
# (106, 322)
# (26, 322)
# (26, 322)
#                        Total killed(t)  Female killed(t)  Youth killed(t)  \
# Province   Event Date
# province 7 2018-12-02              0.0               0.0              0.0
#            2018-12-09              0.0               0.0              0.0
#            2018-12-16              0.0               0.0              2.0
#            2018-12-23              0.0               0.0              0.0
#            2018-12-30              1.0               0.0              0.0
#
#                        Total injured(t)  Female injured(t)  Total raped(t)  \
# Province   Event Date
# province 7 2018-12-02               0.0                0.0             1.0
#            2018-12-09               0.0                0.0             1.0
#            2018-12-16               0.0                0.0             0.0
#            2018-12-23               0.0                0.0             0.0
#            2018-12-30               1.0                1.0             0.0
#
#                        Female raped(t)  Youth raped(t)  Total abducted(t)  \
# Province   Event Date
# province 7 2018-12-02              1.0             1.0                0.0
#            2018-12-09              1.0             1.0                0.0
#            2018-12-16              0.0             0.0                0.0
#            2018-12-23              0.0             0.0                0.0
#            2018-12-30              0.0             0.0                0.0
#
#                        Female abducted(t)                 ...                  \
# Province   Event Date                                     ...
# province 7 2018-12-02                 0.0                 ...
#            2018-12-09                 0.0                 ...
#            2018-12-16                 0.0                 ...
#            2018-12-23                 0.0                 ...
#            2018-12-30                 0.0                 ...
#
#                        Actor 2 - Affiliation_security forces - apf(t)  \
# Province   Event Date
# province 7 2018-12-02                                             0.0
#            2018-12-09                                             0.0
#            2018-12-16                                             0.0
#            2018-12-23                                             0.0
#            2018-12-30                                             0.0
#
#                        Actor 2 - Affiliation_security forces - army(t)  \
# Province   Event Date
# province 7 2018-12-02                                              0.0
#            2018-12-09                                              0.0
#            2018-12-16                                              0.0
#            2018-12-23                                              0.0
#            2018-12-30                                              0.0
#
#                        Actor 2 - Affiliation_security forces - police(t)  \
# Province   Event Date
# province 7 2018-12-02                                                0.0
#            2018-12-09                                                0.0
#            2018-12-16                                                0.0
#            2018-12-23                                                0.0
#            2018-12-30                                                0.0
#
#                        Actor 2 - Affiliation_security forces - security forces (t)  \
# Province   Event Date
# province 7 2018-12-02                                                0.0
#            2018-12-09                                                0.0
#            2018-12-16                                                0.0
#            2018-12-23                                                0.0
#            2018-12-30                                                0.0
#
#                        Actor 2 - Affiliation_students(t)  \
# Province   Event Date
# province 7 2018-12-02                                0.0
#            2018-12-09                                0.0
#            2018-12-16                                0.0
#            2018-12-23                                0.0
#            2018-12-30                                0.0
#
#                        Actor 2 - Affiliation_unclear(t)  \
# Province   Event Date
# province 7 2018-12-02                               0.0
#            2018-12-09                               0.0
#            2018-12-16                               0.0
#            2018-12-23                               0.0
#            2018-12-30                               0.0
#
#                        Actor 2 - Youth/non-youth_na(t)  \
# Province   Event Date
# province 7 2018-12-02                              1.0
#            2018-12-09                              2.0
#            2018-12-16                              2.0
#            2018-12-23                              2.0
#            2018-12-30                              0.0
#
#                        Actor 2 - Youth/non-youth_noyouth(t)  \
# Province   Event Date
# province 7 2018-12-02                                   0.0
#            2018-12-09                                   0.0
#            2018-12-16                                   0.0
#            2018-12-23                                   0.0
#            2018-12-30                                   0.0
#
#                        Actor 2 - Youth/non-youth_unknown(t)  \
# Province   Event Date
# province 7 2018-12-02                                   0.0
#            2018-12-09                                   0.0
#            2018-12-16                                   0.0
#            2018-12-23                                   0.0
#            2018-12-30                                   0.0
#
#                        Actor 2 - Youth/non-youth_youth(t)
# Province   Event Date
# province 7 2018-12-02                                 1.0
#            2018-12-09                                 1.0
#            2018-12-16                                 1.0
#            2018-12-23                                 1.0
#            2018-12-30                                 2.0
#
# [5 rows x 321 columns]

# %% [markdown]
# When the holdout percentage (holdout_pc) is set to .25 the holdout set represents approximately the final 6 months of 2018.  The need for the holdout set is complicated by the fact that this is time series analysis. Procedures needed to be tweaked to ensure that the model *never* "sees" future data when it is being trained, which may render the holdout set irrelevant. It has been removed for now

# %% [markdown]
# ## Train predictive models:

# %% [markdown]
# The following is a core set of functions for training and testing various machine learning models. The output is a dry run used to ensure the functions are working.

# %%
#Train and test a given model

#import modules
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import BayesianRidge
#from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Imputer
#from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import check_cv
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor 
import matplotlib.dates as mdates

#create imputer for nan values - this module can be used to replace missing values
#with something that won't cause an error
imp = Imputer(missing_values='NaN', strategy = 'mean')


def plot_model(y_test, y_pred):
    '''Function to visualize what the model is doing to assist in evaluation'''
    #module for placing tick locations by month
    months = mdates.MonthLocator()  
    
    #put the predictions and desired values in a dataframe next to each other
    sync = pd.DataFrame(y_pred, index=y_test.index)
    
    #set style and colors
    sns.set_style('darkgrid')
    sns.set_palette(catpal)
    
    #1. plot predictions vs. ground truth in a time series
    
    #create subplots
    f, ax = plt.subplots(2,1, figsize=(14,6), sharex=True)
        
    #plot the input values - removed
    #ax[0].plot(X_test.sort_index())
    #ax[0].set_title('Test Input (previous weeks)')
    
    #plot the actual values
    ax[0].plot(y_test.sort_index(), )
    ax[0].set_title('Actual values')
    
    #plot the predictions
    ax[1].plot(sync.sort_index())
    ax[1].set_title("Forecast (from data up to prior week)")
    
    #label and show the plots 
    ax[1].set_ylim(ax[0].get_ylim())
    ax[1].set_xlabel('Time')
    ax[0].set_ylabel('Values')
    
    for x in range(2):
        ax[x].xaxis.set_minor_locator(months)
        ax[x].tick_params(which="both", bottom=True)
        ax[x].grid(which='minor')
    ax[0].legend(labels=y_test.columns)
    plt.rcParams.update({'font.size': 10})
    plt.show()
    
    
    #Plot cross validations - scatterplots of predictions v. actual values in 4 different time ranges 
    f, ax = plt.subplots(1,4, figsize=(14,3), sharey=False)
    qsplit = TimeSeriesSplit(n_splits=4)
    frm = '%Y-%m'
    x=0
    for _, test_index in qsplit.split(y_test):
        for var in range(y_test.shape[1]):
            sns.regplot(y_test.iloc[test_index,var], sync.iloc[test_index,var], ax=ax[x], color=catpal[var], label=y_test.columns[var])
        idx = y_test.iloc[test_index,:].index.strftime(frm)
        datestr = str(idx[0]) + ' - ' + str(idx[-1])
        ax[x].set_title(datestr)
        ax[x].set_xlabel('Actual Values')
        ax[x].set_ylabel('')
        x += 1
    
    #show the plot
    f.suptitle('Cross validated forecast compared to actual values', y=1.1)
    ax[0].set_ylabel('Forecast Values')
    plt.show()
    
    #plot a comparison of the actual values next to the predictions overall
    f, ax = plt.subplots(figsize=(14,8))

    for var in range(y_test.shape[1]):
        sns.regplot(y_test.iloc[:,var], sync.iloc[:,var], ax=ax, label=y_test.columns[var])
    ax.set_title('Forecast compared to actual values')
    ax.set_ylabel('Forecast Values')
    ax.set_xlabel('Actual Values')
    
    if y_test.shape[1] < 15:
        ax.legend(bbox_to_anchor=(1,1))
    
    #show the plot
    plt.show()

def test_model(X_train, X_test, y_train, model):
    '''Function to make predicitons using the model based on training input'''
    
    #impute any NaN values
    imp.fit_transform(X_train, y_train)
    
    #fit the model to the training set
    model.fit(X_train, y_train)

    #predict outcomes based on training set
    y_pred = model.predict(X_test)
    
    #bandaid to set negative predictions to 0
    np.clip(y_pred, a_min=0, a_max=None, out=y_pred)
    
    #return the predictions and trained model
    return y_pred, model 




def score_model(y_test, y_pred, verbose=False):
    '''fuction to score the model according to several metrics and return those metrics'''
    
    #impute any NaN values
    imp.fit_transform(y_test, y_pred)
    
    #score models
    r_2 = r2_score(y_test.astype(float), y_pred.astype(float), multioutput='raw_values')
    ev = explained_variance_score(y_test.astype(float), y_pred.astype(float), multioutput='raw_values')
    rmse = np.sqrt(mean_squared_error(y_test.astype(float), y_pred.astype(float), multioutput='raw_values'))
       
    if verbose > 0:
        #Plot what these look like with fuction above if asked to
        plot_model(y_test, y_pred)
    
    #return train_score, test_score, r_2, ev, rmse, coefs, 
    return r_2, ev, rmse
    
def cv_score(y_test, y_pred):
    '''crossvalidate scores for continuiously trained time series'''
   
    #define varables for data frames - Note: these are not litterally yearly quarters. They don't line up that way
    qlist = ['Q1','Q2','Q3','Q4']
    vlist = ['r_2','explained_variance','root_mean_squared_error']
    cv = {}
    
    #instantiate time series splitter
    qsplit = TimeSeriesSplit(n_splits=4)
    
    #loop through splits and save scores to dataframe
    x=0
    for _, test_index in qsplit.split(y_test):
        r_2, ev, rmse = score_model(y_test.iloc[test_index], y_pred.iloc[test_index])
        scores = pd.DataFrame(index=y_test.columns, columns=vlist)
        scores.loc[:,'r_2'] = r_2
        scores.loc[:,'explained_variance'] = ev
        scores.loc[:,'root_mean_squared_error'] = rmse
        #save the dataframe in a dictionary
        cv[qlist[x]] = scores 
        x += 1
    
    #concat the dataframes together and return
    cv_df = pd.concat([cv['Q1'],cv['Q2'],cv['Q3'],cv['Q4']], axis=1, keys=cv.keys())
    return cv_df


def try_model(X, y, model, verbose=0, random_state=None):
    '''fuction to that takes a given model and a dataset, and evaluates the model
        -gives the option to plot relivant data
        -returns relivant scoring metrics'''

    #Split X and Y into training and testing sets using time series split. 
    #In this case X will consist of every week up until a given week in y,
    tscv = TimeSeriesSplit(n_splits=len(y)-1)
    
    #initialize data frames to fill with predictions and baseline scores
    y_pred = pd.DataFrame(index=y.index, columns=y.columns)
    y_control = y_pred.copy(deep=True)
    
    #A warm start adds training to a model rather than retraining it for new data.
    #to use one we have to increase the number of estimators with every run
    try: #first try getting the base no. of estimators from the model
        warm_start = model.get_params(deep=True)['n_estimators']
    except:#if that doesn't work just start with 0
        warm_start = 0
    
    #loop through every index of the time series split (every week)
    for train_index, test_index in tscv.split(X):
        
        #set training and testing values based on index.
        #Again X is every week before a given week in y.
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        #If model is using a warm start, set number of estimators based on
        #how many runs we've done, and change training set to a sliding window for efficency
        try:
            if model.get_params(deep=True)['warm_start'] == True:
                model.set_params(n_estimators=warm_start) 
                X_train, y_train = X_train[-16:], y_train[-16:]
        except: #if that doesn't work forget it
            pass
        
        y_control.iloc[test_index] = y.iloc[test_index-1].values
        
        #use functions above to train model and create predictions_
        try:
            y_pred.iloc[test_index], model = test_model(X_train, X_test, y_train, model)
        except:
            pass  #handle exception to return data up to any failure point
            
        warm_start+=10
        #debug logging
        
        if test_index.sum() < 0:
            print('\nRun:\t',test_index)
            print('X_train:\t', X_train.iloc[:,:2])
            print('y_train:\t', y_train.iloc[:,:2])
            print('X_test:\t', X_test.iloc[:,:2])
            print('y_pred:\t', y_pred.iloc[test_index])
            print('y_test:\t', y_test.iloc[:,:2])
            print('y_control:\t', y_control.iloc[test_index])
    
    y_test = y #for better plotting
    
    #return train/test split, predicitons and control - with front two datapoints chopped off 
    return X_train[2:], X_test[2:], y_train[2:], y_test[2:], y_pred[2:], y_control[2:].fillna(0)
    #lets not chop them off anymore
    #return X_train, X_test, y_train, y_test, y_pred, y_control.fillna(0) 
    
#define y - we'll just predict two variables for the dry run
y = y_week.loc[:,['Total killed(t)','Total injured(t)']] 

#instantiate a model to feed through the core functions
model = RandomForestRegressor(random_state=56)

#give the functions to try a given model a dry run to see if it works.
print('Dry Run:')

#try the model
X_train, X_test, y_train, y_test, y_pred, y_control = try_model(X_week, y, model, verbose = 2, random_state=56)
#score the model
dry_scores = score_model(y_test, y_pred, verbose=True)

#find and show the baseline scores - assuming one week will continue as the next
print('Baseline/Control - Forecast assuming each week has the same value as the previous week:')
control_scores = score_model(y_test, y_control, verbose=True)

#find and plot the crossvalidated scores

#print summary scores
dry_cv = cv_score(y_test, y_pred)
print('R_2:\t\t\t',dry_scores[0])
print('Explained Variance:\t', dry_scores[1])
print('Mean Squared Error:\t', dry_scores[2])
print('\nCross Validation:')

dry_cv
# Out:
# Dry Run:
# Baseline/Control - Forecast assuming each week has the same value as the previous week:
# R_2:			 [ 0.00444711  0.2434568 ]
# Explained Variance:	 [ 0.00524108  0.24580482]
# Mean Squared Error:	 [  3.13246033  19.67602993]
#
# Cross Validation:
#                         Q1                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.128599          -0.114899                2.949831
# Total injured(t) -0.384468          -0.271100               20.198738
#
#                         Q2                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.127623          -0.121389                2.622689
# Total injured(t) -0.118054          -0.116300               17.800463
#
#                         Q3                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.261059          -0.255108                3.857525
# Total injured(t) -0.025565           0.094963               15.956002
#
#                         Q4
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.030979           0.099969                3.044421
# Total injured(t) -0.454960          -0.182948               10.580903

# %% [markdown]
# The visualization above is the output of a "dry run" of one model, with a prediction of only two variables to ensure the core functions are working correctly,
#
# Ideally trends in the forecast for a given week or month, should line up with the trends in the actual values for that week. There appears to be a tendency of the forecast to lag behind trends in actual values, but in a few examples of the dry run the peaks and valleys in the trend and the forecast seem to match perfectly. This could be the result of random variation, but may also indicate the presence of leading indicators.
#
# In the scatter plot comparing actual values to forecast values, an ideal forecast would be a 45 degree line of dots representing a forecast values that matched actual values.
#
# Scores are indicated numerically by Root Mean Squared Error (an absolute interpretation of the size of the error, meaning large values are worse), explained variance (how much of the variance in the forecast is explained by the model) and R-squared(the proportion of the variance in the dependent variable that is predictable from the independent variable). The maximum score for the latter two is 1, with negative values indicating that using the mean of the actual values would result in a better forecast.
#
# In a final product on the Nepal Monitor Platform, R-squared or explained variance could be used to indicate accuracy percentages, while Root Mean Squared Error could be transformed into margin of error or confidence interval to show a range in which actual values are likely to fall.
#
# A second set of plots is produced to show how a baseline model, which simply assumes a given week will have the same value of the previous week, would perform. To be acceptable, a model should have high positive R-squared and Explained variance scores, while also beating baseline scores.

# %%
def try_model_province(X, y, model, verbose=0, random_state=None):
    '''fuction to that takes a given model and a dataset, and evaluates the model on a per province basis
        -gives the option to plot relivant data
        -returns relivant scoring metrics'''
    
    
    #initialize empty dataframes for prediction and control values
    y_pred = pd.DataFrame(index=y.index, columns=y.columns)
    y_control = pd.DataFrame(index=y.index, columns=y.columns) 
    
    #set warmstart value for number of estimators   
    warm_start=10
    
    #loop through range of weeks
    for week in range(99):
        #loop through each province
        for pro in range(1,8):
            #extract data up to current week for given province
            province = 'province '+str(pro)
            X_prov, y_prov = X.loc[province], y.loc[province] 
            
            #split the data into training and testing indexes
            tscv = TimeSeriesSplit(n_splits=int(len(y_prov)-1))
            index = list(tscv.split(X.loc[province])) 
            train_index, test_index = index[week]
            X_train, X_test = X_prov.iloc[train_index], X_prov.iloc[test_index]
            y_train, y_test = y_prov.iloc[train_index], y_prov.iloc[test_index]
            
            #if model is using a warm start, set number of parameters based on
            #how many runs we've done, and change training set to a sliding window
            try:
                if model.get_params(deep=True)['warm_start'] == True:
                    model.set_params(n_estimators=warm_start) 
                    X_train, y_train = X_train[-16:], y_train[-16:]
            except:
                pass
                
            y_pred.loc[(province,),].iloc[test_index], model\
            = test_model(X_train, X_test, y_train, model)
            #model.fit(X_train.loc[(province,),:], y_train.loc[(province,),:])
            warm_start += 2
            
            #debug logging
            y_control.iloc[test_index] = y.iloc[test_index-1]
            if test_index.sum() < 0:
                print('\nRun:\t',test_index)
                print(province+':')
                print('X_train:\t', X_train.iloc[:,:2])
                print('y_train:\t', y_train.iloc[:,:2])
                print('X_test:\t', X_test.iloc[:,:2])
                print('y_pred:\t', y_pred.loc[province].iloc[test_index])
                print('y_test:\t', y_test.iloc[:,:2])
    
    y_test = y #we have been using only 1 y week at a time - return them all for better plotting
    
    #return train/test split, predicitons and control - with front two datapoints chopped off 
    return X_train[2:], X_test[2:], y_train[2:], y_test[2:], y_pred[2:], y_control[2:].fillna(0) 

#trying a dry run with provinces
#define y
y = y_province.loc[:,['Total killed(t)','Total injured(t)']] # > in_week.loc[:,'Total killed'].quantile(.5)      

model = RandomForestRegressor(random_state=56, warm_start=False)

print('Dry Run (province 2):')
#give the function to try a given model a dry run to see if it works.
X_train, X_test, y_train, y_test, y_pred, y_control = try_model_province(X_province, y, model, verbose = 2, random_state=56)
dry_scores = score_model(y_test.loc['province 2'], y_pred.loc['province 2'].fillna(0), verbose=True)
dry_cv_prov = cv_score(y_test.loc['province 2'], y_pred.loc['province 2'].fillna(0))
print('R_2:\t\t\t',dry_scores[0])
print('Explained Variance:\t', dry_scores[1])
print('Mean Squared Error:\t', dry_scores[2])
print('\nCross Validation:')
#for x in ['Q1','Q2','Q3','Q4']:
#    print('\n',x)
#    print(dry_cv[x])
dry_cv_prov
# Out:
# Dry Run (province 2):
# R_2:			 [-0.04843044 -0.2043495 ]
# Explained Variance:	 [-0.03756372 -0.19682051]
# Mean Squared Error:	 [ 1.74209806  9.06808627]
#
# Cross Validation:
#                         Q1                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.125537           0.056075                1.849324
# Total injured(t) -0.339829          -0.213555               13.153598
#
#                         Q2                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.087843          -0.087631                1.707546
# Total injured(t) -0.345278          -0.336513                8.023596
#
#                         Q3                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.082389          -0.039581                2.322663
# Total injured(t) -0.545628          -0.526107                5.127006
#
#                         Q4
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.602725          -0.535281                1.137457
# Total injured(t) -0.595994          -0.507985                5.252074

# %% [markdown]
# The function above trains and tests a model just like before, but does it for every province separately. Using the province_wise dataframe. All provinces are tested and scored at once, but only "Province 2" is displayed above. "Province 3" is displayed below.

# %%
province = 'province 3'
dry_scores = score_model(y_test.loc[province], y_pred.loc[province].fillna(0), verbose=True)
dry_cv_prov = cv_score(y_test.loc[province], y_pred.loc[province].fillna(0))
print('R_2:\t\t\t',dry_scores[0])
print('Explained Variance:\t', dry_scores[1])
print('Mean Squared Error:\t', dry_scores[2])
print('\nCross Validation:')
#for x in ['Q1','Q2','Q3','Q4']:
#    print('\n',x)
#    print(dry_cv[x])
dry_cv_prov
# Out:
# R_2:			 [-0.14402561 -0.10428133]
# Explained Variance:	 [-0.12519676 -0.09333611]
# Mean Squared Error:	 [ 1.47072053  8.58518909]
#
# Cross Validation:
#                         Q1                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.195260          -0.139635                1.964567
# Total injured(t) -0.872588          -0.647939                6.860411
#
#                         Q2                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.320444          -0.320296                1.349250
# Total injured(t) -0.958428          -0.908873                8.771192
#
#                         Q3                                             \
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.059371          -0.043144                1.539016
# Total injured(t) -0.107803          -0.104330               11.226457
#
#                         Q4
#                        r_2 explained_variance root_mean_squared_error
# Total killed(t)  -0.292308          -0.241442                1.104105
# Total injured(t) -3.328765          -3.061358                2.184142

# %% [markdown]
# ### Find variables with the best prediction scores

# %%
def get_coefs(X_train, y_train, model):
    '''get an array of coefficents or feature importances from the model - working for RandomForrest'''
    #create an empty array (no. output features * no. input features)     
    coefs = np.empty((y_train.shape[1], X_train.shape[1]))
    
    #first try looping through and getting the feature coefs for every estimator - for MultiOutputRegressor
    try:
        for n in range(len(model.estimators_)):
            coefs[n] = model.estimators_[n].coef_
    except:
        try: #if that throws an error just export the coef_ array directly from the model    
            coefs = model.coef_#np.empty(y_pred.shape)
        except:
            try: #if that throws an error we are probably using RandomForrest, and we just need the importances
                print('unable to fetch coefs, trying importance...')
                coefs = model.feature_importances_
                
            except: #if that throws an error we failed and we need to admit it
                print('Failed!')
    
    #creat a dataframe of coefficents and their feature labels
    print('Total feature coefs:', coefs.shape)
    #if coefs.shape[0] > 1:
    try: #first try making the dataframe out of the X_columns
        coefframe = pd.DataFrame(coefs, columns=['All Variables'], index=X_train.columns)
    except: #if that didn't work but it is more than one, it may be from a neural net.
        #find how many layers there are in the net.
        n_layers=coefs.shape[0]
        #make a list of the levels
        layerlst = []
        for x in range(n_layers):
            layerlst.append('layer_'+str(x))
        #print(layerlst)
            #make a dataframe with the list of layers as the index
        coefframe = pd.DataFrame(coefs, index=layerlst, columns=X_train.columns)
        coefframe = coefframe.transpose() 
    
    #return the coefficent dataframe
    return coefframe

def interpret_coefs(coefframe, X_train, cats):
    '''plot histograms of the coefficients as well and bar charts of the top coefficients'''
    
    #plot histogram of coefficents for each variable in the categores passed 
    #loop through a range the length of the passed in categories
    n = 0
    for cat in cats:
        try: #first try plotting a histogram of coefs label according to passed in cat
            sns.distplot(coefframe[cat], color=catpal[n], label=cat)#.sort_values(1))
            print('plotting', cats[cat])
            plt.xlabel('feature coefficient', fontsize='x-large')
        except:
            pass
            #print("couldn't plot ", cats[cat])
        n += 1
    try:
        sns.distplot(coefframe)
        plt.xlabel('feature importance', fontsize='x-large')
        
    except:
        pass
    
   
    plt.legend(bbox_to_anchor=(1,1))
    plt.ylabel('density at given value', fontsize='x-large')
    plt.rcParams.update({'font.size': 13})
    plt.show()
    
  
        
    
    #plot top coefficents for each variable - currently doesn't do it, plotting top for one. 
    try:
        serieslist = []
        for cat in cats:
            serieslist.append(coefframe.loc[:,cat].nlargest(5))
            data = concat(serieslist, axis=1)
            print('Top feature coefs:\n', data.head())
    except:
        data=coefframe.nlargest(10, coefframe.columns)
        print('\nTop feature coefs:\n', data.head())
    n=0
    for cat in data.columns: 
        sns.swarmplot(y=data.index, x=cat, data=data, color=catpal[n], alpha=.5, size=10)
        n += 1
        
        #plt.legend()
    plt.ylabel('input category', fontsize='x-large')
    plt.xlabel('coef / importance', fontsize='x-large')
    plt.legend()
    plt.show()
    #return coefframe

# %%
#find which variables have the best scores

def find_var (X, df, model, n_true, verbose=False, random_state=None, s_plot=0, n_plot=1, province=''):
   
    #filter out varables where the perentage "true" is less than n_true, to avoid completely unbalanced data
    pc_true = [sum(df[x] >= 1)/len(df[x])*100 > n_true for x in df.columns]
    y = df.loc[:,pc_true]
    
    if province != '':  
        X_train, X_test, y_train, y_test, y_pred, y_control = try_model_province(X, y, model, verbose=False)
        y_test = y_test.loc[province].dropna()
        y_pred = y_pred.loc[province].fillna(0)
        y_control = y_control.loc[province].fillna(0)
    
    else:
        X_train, X_test, y_train, y_test, y_pred, y_control = try_model(X, y, model, verbose=False)
    
    
    #score the model
    r_2, ev, rmse = score_model(y_test, y_pred, verbose=False)
    
    #Score the model based on control (simply continuing the values from the previous week). 
    r_2_c, ev_c, rmse_c, = score_model(y_test, y_control, verbose=False)
    
    
    #save all these scores in data frames
    collist = ['r_2','explained_variance','root_mean_squared_error']    
    scores = pd.DataFrame(index=df.columns, columns=(collist))
    scores_c = pd.DataFrame(index=df.columns, columns=(collist))
    
    scores.loc[pc_true,'r_2'] = r_2
    scores.loc[pc_true,'explained_variance'] = ev
    scores.loc[pc_true,'root_mean_squared_error'] = rmse

    scores_c.loc[pc_true,'r_2'] = r_2_c
    scores_c.loc[pc_true,'explained_variance'] = ev_c
    scores_c.loc[pc_true,'root_mean_squared_error'] = rmse_c
    
    #crossvalidate quarterly periods
    cv_scores = cv_score(y_test, y_pred)
    
    #calculate cv means
    cv_mean = pd.DataFrame(index=cv_scores.index)
    #cv_mean.set_columns(['cv_mean',collist],inplace=True)
    for x in range(3):
        col = collist[x]
        cv_mean.loc[:,col] = [cv_scores.iloc[y,x::3].agg('mean') for y in range(len(cv_scores))]
    
    if verbose > 1:
        #print scores
        #print('total train score:', train_score )
        #print('total test score:', test_score)
        print('\ntop score r_2:',scores['r_2'].max())
        print('top score explained variance:',ev.max())
        print('best score rmse:',rmse.min()) 
        
        print('\ncontrol test - forcast using exact values of previous week:')
        print('top score r_2:',r_2_c.max())
        print('top score explained variance:',ev_c.max())
        print('best score rmse:',rmse_c.min())
    
    #add crossvalidated scores to dataframe
    
    cv_mean.columns = pd.MultiIndex.from_product([['cv_mean'],collist])
    scores.columns = pd.MultiIndex.from_product([['scores'],collist])
    scores_c.columns = pd.MultiIndex.from_product([['control_scores'],collist])
    
    scores = pd.concat([scores, scores_c, cv_mean, cv_scores], axis=1)    
    
    #filter out explained variance scores below 
    top = scores.loc[scores[('scores','explained_variance')] > -1].sort_values(('scores','r_2'), ascending=False)
    
    #filter out scores that don't beat the control - (errors are higher than control)
    worse = top.loc[top[('scores','root_mean_squared_error')] > top[('control_scores','root_mean_squared_error')]]
    top.drop(worse.index, inplace=True)
    
    #find differences between model and control in R_2
    diff = (top[('scores','r_2')] - top[('control_scores','r_2')])#.sort_values(ascending=False)
    
    #filter out low differences with control
    top = top.loc[diff > .1]
    
    
    if verbose > 0:
        #plot what the best scores look like. 
        print("\nTop Scoring Variables:")
        yfilt = [ x in top[s_plot:n_plot].index.tolist() for x in y_test.columns]
        plot_model(y_test.loc[:,yfilt], y_pred.loc[:,yfilt])
    
    if verbose > 1:
    #plot what the control scores look like
        #print(y_control)
        plot_model(y_test.loc[:,yfilt], y_control.loc[:,yfilt])
    
    #top_scores = score_model(X_train, X, y_train.loc[:,top.index[:3]], y.loc[:,top.index[:3]], y_pred.loc[:,top.index[:3]], model, verbose=verbose)
    #top_scores = find_var(X_week, y_week.loc[:,better.index[:3]], model, n_true=20, verbose=2, random_state=38)
    return scores, top

if __name__ == '__main__': #protect windows from parallel processes(if you run windows)
#for step in range(5,y_week.shape[1])[::5]:
    #model = MultiOutputRegressor(ARDRegression(), n_jobs=-1)
    #model = MultiOutputRegressor(BayesianRidge(), n_jobs=-1)
    #model = LinearRegression()
    model = RandomForestRegressor(random_state=56, warm_start=False)
    
    print("Finding Variables...")
    scores, top = find_var(X_week, y_week, model, n_true=20, verbose=1, n_plot=1)
    #get feature coeficents and feature importance
    #coefs = get_coefs(X_train, y_train, model)
    #coefframe = interpret_coefs(coefs,X_train,top.index)
    
    #print top 10 scores that beat control
top[:10]
# Out:
# Finding Variables...
#
# Top Scoring Variables:
#                                                       scores  \
#                                                          r_2
# Actor 1 - Youth/non-youth_unknown(t)                0.328915
# Cause - Primary_gender-based violence - rape/se...  0.312911
# Event Form - Primary_violent - sexual assault(t)    0.311463
# Collective / Interpersonal_collective(t)            0.294845
# Total raped(t)                                      0.269537
# Cause - Primary_political - election-related in...   0.26635
# Female raped(t)                                     0.258723
# Actor 2 - Youth/non-youth_unknown(t)                0.235263
# Actor 2 - Youth/non-youth_na(t)                     0.209668
# Youth raped(t)                                      0.189594
#
#                                                                        \
#                                                    explained_variance
# Actor 1 - Youth/non-youth_unknown(t)                           0.3476
# Cause - Primary_gender-based violence - rape/se...           0.351648
# Event Form - Primary_violent - sexual assault(t)             0.351394
# Collective / Interpersonal_collective(t)                     0.305447
# Total raped(t)                                               0.326058
# Cause - Primary_political - election-related in...            0.26636
# Female raped(t)                                              0.310585
# Actor 2 - Youth/non-youth_unknown(t)                         0.245047
# Actor 2 - Youth/non-youth_na(t)                              0.219693
# Youth raped(t)                                               0.244049
#
#                                                                             \
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                               19.4482
# Cause - Primary_gender-based violence - rape/se...                 4.98508
# Event Form - Primary_violent - sexual assault(t)                   4.93109
# Collective / Interpersonal_collective(t)                           23.2195
# Total raped(t)                                                     4.99489
# Cause - Primary_political - election-related in...                 23.6048
# Female raped(t)                                                    4.86756
# Actor 2 - Youth/non-youth_unknown(t)                               8.65399
# Actor 2 - Youth/non-youth_na(t)                                     15.974
# Youth raped(t)                                                     4.48832
#
#                                                    control_scores  \
#                                                               r_2
# Actor 1 - Youth/non-youth_unknown(t)                     0.012414
# Cause - Primary_gender-based violence - rape/se...       0.176401
# Event Form - Primary_violent - sexual assault(t)          0.15976
# Collective / Interpersonal_collective(t)                0.0280466
# Total raped(t)                                         -0.0101023
# Cause - Primary_political - election-related in...       0.055514
# Female raped(t)                                        -0.0162102
# Actor 2 - Youth/non-youth_unknown(t)                    -0.359472
# Actor 2 - Youth/non-youth_na(t)                         0.0817405
# Youth raped(t)                                          -0.187906
#
#                                                                        \
#                                                    explained_variance
# Actor 1 - Youth/non-youth_unknown(t)                        0.0126509
# Cause - Primary_gender-based violence - rape/se...           0.176493
# Event Form - Primary_violent - sexual assault(t)             0.159854
# Collective / Interpersonal_collective(t)                    0.0281704
# Total raped(t)                                              -0.010059
# Cause - Primary_political - election-related in...           0.055514
# Female raped(t)                                            -0.0161639
# Actor 2 - Youth/non-youth_unknown(t)                        -0.359412
# Actor 2 - Youth/non-youth_na(t)                             0.0819492
# Youth raped(t)                                              -0.187873
#
#                                                                             \
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                               23.5927
# Cause - Primary_gender-based violence - rape/se...                 5.45788
# Event Form - Primary_violent - sexual assault(t)                    5.4473
# Collective / Interpersonal_collective(t)                           27.2605
# Total raped(t)                                                     5.87367
# Cause - Primary_political - election-related in...                 26.7826
# Female raped(t)                                                    5.69919
# Actor 2 - Youth/non-youth_unknown(t)                               11.5384
# Actor 2 - Youth/non-youth_na(t)                                    17.2183
# Youth raped(t)                                                     5.43405
#
#                                                      cv_mean  \
#                                                          r_2
# Actor 1 - Youth/non-youth_unknown(t)               -1.149257
# Cause - Primary_gender-based violence - rape/se... -0.024035
# Event Form - Primary_violent - sexual assault(t)   -0.042428
# Collective / Interpersonal_collective(t)           -1.688494
# Total raped(t)                                     -0.075821
# Cause - Primary_political - election-related in...  0.095939
# Female raped(t)                                    -0.076442
# Actor 2 - Youth/non-youth_unknown(t)               -2.125865
# Actor 2 - Youth/non-youth_na(t)                    -0.958400
# Youth raped(t)                                     -0.111187
#
#                                                                        \
#                                                    explained_variance
# Actor 1 - Youth/non-youth_unknown(t)                        -0.299882
# Cause - Primary_gender-based violence - rape/se...           0.074992
# Event Form - Primary_violent - sexual assault(t)             0.066438
# Collective / Interpersonal_collective(t)                    -0.538429
# Total raped(t)                                               0.055353
# Cause - Primary_political - election-related in...           0.098113
# Female raped(t)                                              0.042937
# Actor 2 - Youth/non-youth_unknown(t)                        -0.701860
# Actor 2 - Youth/non-youth_na(t)                             -0.439220
# Youth raped(t)                                              -0.007266
#
#                                                                             \
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                             16.889809
# Cause - Primary_gender-based violence - rape/se...                5.360744
# Event Form - Primary_violent - sexual assault(t)                  5.277508
# Collective / Interpersonal_collective(t)                         20.358900
# Total raped(t)                                                    5.361708
# Cause - Primary_political - election-related in...               18.661046
# Female raped(t)                                                   5.251049
# Actor 2 - Youth/non-youth_unknown(t)                              5.959000
# Actor 2 - Youth/non-youth_na(t)                                  15.255263
# Youth raped(t)                                                    4.861415
#
#                                                           Q1  \
#                                                          r_2
# Actor 1 - Youth/non-youth_unknown(t)               -0.152375
# Cause - Primary_gender-based violence - rape/se... -0.257792
# Event Form - Primary_violent - sexual assault(t)   -0.294145
# Collective / Interpersonal_collective(t)           -0.095777
# Total raped(t)                                     -0.240686
# Cause - Primary_political - election-related in...  0.033177
# Female raped(t)                                    -0.220517
# Actor 2 - Youth/non-youth_unknown(t)               -0.084896
# Actor 2 - Youth/non-youth_na(t)                    -0.266594
# Youth raped(t)                                     -0.307052
#
#                                                              ...            \
#                                                              ...
# Actor 1 - Youth/non-youth_unknown(t)                         ...
# Cause - Primary_gender-based violence - rape/se...           ...
# Event Form - Primary_violent - sexual assault(t)             ...
# Collective / Interpersonal_collective(t)                     ...
# Total raped(t)                                               ...
# Cause - Primary_political - election-related in...           ...
# Female raped(t)                                              ...
# Actor 2 - Youth/non-youth_unknown(t)                         ...
# Actor 2 - Youth/non-youth_na(t)                              ...
# Youth raped(t)                                               ...
#
#                                                                             \
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                             17.798216
# Cause - Primary_gender-based violence - rape/se...                3.866782
# Event Form - Primary_violent - sexual assault(t)                  3.753665
# Collective / Interpersonal_collective(t)                         24.187218
# Total raped(t)                                                    3.658825
# Cause - Primary_political - election-related in...               23.048178
# Female raped(t)                                                   3.825441
# Actor 2 - Youth/non-youth_unknown(t)                              5.903812
# Actor 2 - Youth/non-youth_na(t)                                  18.032457
# Youth raped(t)                                                    3.802105
#
#                                                           Q2  \
#                                                          r_2
# Actor 1 - Youth/non-youth_unknown(t)                0.302986
# Cause - Primary_gender-based violence - rape/se...  0.163918
# Event Form - Primary_violent - sexual assault(t)    0.178897
# Collective / Interpersonal_collective(t)            0.279857
# Total raped(t)                                      0.064526
# Cause - Primary_political - election-related in...  0.350579
# Female raped(t)                                     0.054822
# Actor 2 - Youth/non-youth_unknown(t)                0.559112
# Actor 2 - Youth/non-youth_na(t)                     0.073936
# Youth raped(t)                                      0.088078
#
#                                                                        \
#                                                    explained_variance
# Actor 1 - Youth/non-youth_unknown(t)                         0.306043
# Cause - Primary_gender-based violence - rape/se...           0.239779
# Event Form - Primary_violent - sexual assault(t)             0.244112
# Collective / Interpersonal_collective(t)                     0.280202
# Total raped(t)                                               0.195391
# Cause - Primary_political - election-related in...           0.354646
# Female raped(t)                                              0.185046
# Actor 2 - Youth/non-youth_unknown(t)                         0.566072
# Actor 2 - Youth/non-youth_na(t)                              0.079698
# Youth raped(t)                                               0.187948
#
#                                                                             \
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                             24.688692
# Cause - Primary_gender-based violence - rape/se...                6.390657
# Event Form - Primary_violent - sexual assault(t)                  6.209589
# Collective / Interpersonal_collective(t)                         31.522262
# Total raped(t)                                                    6.283072
# Cause - Primary_political - election-related in...               35.948707
# Female raped(t)                                                   6.317634
# Actor 2 - Youth/non-youth_unknown(t)                              7.799808
# Actor 2 - Youth/non-youth_na(t)                                  23.326337
# Youth raped(t)                                                    5.272997
#
#                                                           Q3  \
#                                                          r_2
# Actor 1 - Youth/non-youth_unknown(t)               -2.438439
# Cause - Primary_gender-based violence - rape/se... -0.126452
# Event Form - Primary_violent - sexual assault(t)   -0.169110
# Collective / Interpersonal_collective(t)           -2.419530
# Total raped(t)                                     -0.188766
# Cause - Primary_political - election-related in...  0.000000
# Female raped(t)                                    -0.241400
# Actor 2 - Youth/non-youth_unknown(t)               -2.432599
# Actor 2 - Youth/non-youth_na(t)                    -1.268802
# Youth raped(t)                                     -0.166847
#
#                                                                        \
#                                                    explained_variance
# Actor 1 - Youth/non-youth_unknown(t)                        -1.257233
# Cause - Primary_gender-based violence - rape/se...           0.167471
# Event Form - Primary_violent - sexual assault(t)             0.152470
# Collective / Interpersonal_collective(t)                    -1.425887
# Total raped(t)                                               0.149328
# Cause - Primary_political - election-related in...           0.000000
# Female raped(t)                                              0.071452
# Actor 2 - Youth/non-youth_unknown(t)                        -1.290086
# Actor 2 - Youth/non-youth_na(t)                             -1.031628
# Youth raped(t)                                               0.063724
#
#                                                                             \
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                             13.956325
# Cause - Primary_gender-based violence - rape/se...                5.001850
# Event Form - Primary_violent - sexual assault(t)                  4.804893
# Collective / Interpersonal_collective(t)                         15.119094
# Total raped(t)                                                    4.697180
# Cause - Primary_political - election-related in...               11.657251
# Female raped(t)                                                   4.651290
# Actor 2 - Youth/non-youth_unknown(t)                              5.754650
# Actor 2 - Youth/non-youth_na(t)                                  11.165348
# Youth raped(t)                                                    4.217997
#
#                                                           Q4  \
#                                                          r_2
# Actor 1 - Youth/non-youth_unknown(t)               -2.309199
# Cause - Primary_gender-based violence - rape/se...  0.124187
# Event Form - Primary_violent - sexual assault(t)    0.114644
# Collective / Interpersonal_collective(t)           -4.518529
# Total raped(t)                                      0.061642
# Cause - Primary_political - election-related in...  0.000000
# Female raped(t)                                     0.101328
# Actor 2 - Youth/non-youth_unknown(t)               -6.545079
# Actor 2 - Youth/non-youth_na(t)                    -2.372139
# Youth raped(t)                                     -0.058927
#
#                                                                        \
#                                                    explained_variance
# Actor 1 - Youth/non-youth_unknown(t)                        -0.321566
# Cause - Primary_gender-based violence - rape/se...           0.132710
# Event Form - Primary_violent - sexual assault(t)             0.126862
# Collective / Interpersonal_collective(t)                    -1.049339
# Total raped(t)                                               0.087267
# Cause - Primary_political - election-related in...           0.000000
# Female raped(t)                                              0.121053
# Actor 2 - Youth/non-youth_unknown(t)                        -2.007274
# Actor 2 - Youth/non-youth_na(t)                             -0.787337
# Youth raped(t)                                              -0.004098
#
#
#                                                    root_mean_squared_error
# Actor 1 - Youth/non-youth_unknown(t)                             11.116002
# Cause - Primary_gender-based violence - rape/se...                6.183688
# Event Form - Primary_violent - sexual assault(t)                  6.341885
# Collective / Interpersonal_collective(t)                         10.607026
# Total raped(t)                                                    6.807753
# Cause - Primary_political - election-related in...                3.990050
# Female raped(t)                                                   6.209831
# Actor 2 - Youth/non-youth_unknown(t)                              4.377728
# Actor 2 - Youth/non-youth_na(t)                                   8.496911
# Youth raped(t)                                                    6.152560
#
# [10 rows x 21 columns]

# %% [markdown]
# Here we are asking RandomForrestRegressor to predict all variables one week ahead as best as it can using all variables as input features. We are filtering out variables that don't beat control scores and plotting the top scoring variable. Additionally we are plotting a histogram of the feature importances, and showing the top 10 most important features. It is clear that relatively few features are important to the model. This information can be used for analysis of which variables may be the best indicators of violence, as well as for pruning features out to increase computational efficiency.

# %% [markdown]
# ### Optimize Models

# %%
#Optimize / Tune Model
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

def random_search(params, model, n_iter):
    #define splitter... time series split?
    qsplit = TimeSeriesSplit(n_splits=4)

    #instantiate randomized search - use normal scoring function
    Search = RandomizedSearchCV(model, param_distributions=params, cv=qsplit, n_jobs=-1, n_iter=n_iter)

    #fit X_week, Y_week
    Search.fit(X_week, y_week)

    #find the best scoring model
    best_params = Search.best_params_
    best_score = Search.best_score_
    #show the results
    results = Search.cv_results_
    #print('results:\n',results)
    #define param grid - get params from model - test first
    return best_params, best_score, results

#instantiate model
model = RandomForestRegressor(random_state=56)    

#set paramaters
params = {'n_estimators':range(150,300,1),
          'warm_start':[False],
          'max_depth':range(1,300,1),
          'min_samples_split':np.linspace(0.00000001,.1,100),
          'min_samples_leaf':range(5,6,1),
          'min_weight_fraction_leaf':np.linspace(.0000001,.1,100),
          'max_features':range(150,200,1),
          'max_leaf_nodes':range(180,300,1),
          'min_impurity_decrease':np.linspace(0.000001,.1,100)}

#random search parameters, returning the best scores and results.
best_params, best_score, results = random_search(params, model, 20)
print('\nbest parameters',best_params)
print('best score',best_score)
# Out:
# best parameters {'warm_start': False, 'n_estimators': 217, 'min_weight_fraction_leaf': 0.012121300000000002, 'min_samples_split': 0.030303037272727276, 'min_samples_leaf': 5, 'min_impurity_decrease': 0.073737636363636366, 'max_leaf_nodes': 185, 'max_features': 185, 'max_depth': 280}
# best score -0.402884317452

# %%
#Plot results of parameter search
def plot_params(params, results):
    '''plots the results of a given parameter search for optimization'''
    #set how many plots there will be acourding to the number of parameters
    plotlen = len(params.keys())
    
    #set the hieght of the plot according to 1/3 the number of plots
    plotht = int((plotlen+1)/3)
    
    #print something to show we are working
    print('plotting', plotlen, 'params...')
    
    #create the subplot gird with 3 columns and a hight according to the number of plots
    f, ax = plt.subplots(plotht,3, figsize = (16,plotht*4), sharey=True)

    #loop through random_search results and plot paramater values against scores 
    count = 0
    for key in params.keys():
        ax1 = int(count/3)
        ax2 = count%3
        
        #first try plotting normally.
        try:
            sns.scatterplot(results['param_'+key],results['mean_test_score'], label=key, ax=ax[ax1][ax2])
        
        #If that doesn't work it could be because it's a list of hidden layers on a neural net. Handle that.
        except:
            lst = []
            for item in results['param_'+key]:
                lst.append(item[0])
                #print(lst)
            sns.scatterplot(lst ,results['mean_test_score'], label=key)
        
        plt.legend(bbox_to_anchor=(1,1))
        count += 1
             
        #print(count, ax1, ax2)
    plt.show()
    
plot_params(params, results)
# Out:
# plotting 9 params...

# %% [markdown]
# The results plot above is used to refine the parameter space of the random hyper parameter search in order to tune the model.  The parameter search trains and scores the model 100 times using randomly chosen parameters within the given parameter space. These parameters are then scatterplotted against the resulting score.  Downward trends on either end of a given parameter range can then be eliminated and fed back into the randomized search, until the scatterplots appear random. The resulting tuned parameters are then used for the model going forward.
#
# If the plots above appear random the model is optimized.

# %%
#call find var again, using params from above.  
model = RandomForestRegressor(random_state=56, **best_params)
    
print("Finding Variables...")
scores, top = find_var(X_week, y_week, model, n_true=20, verbose=2, s_plot=3, n_plot=6)

#extract and plot feature coefs
coefframe = get_coefs(X_train, y_train, model)
interpret_coefs(coefs,X_train,top.index)

    #print top 10 scores that beat control
top[:10]
# Out:
# Finding Variables...
#
# top score r_2: 0.33874716267141647
# top score explained variance: 0.344224404072
# best score rmse: 0.420673692195
#
# control test - forcast using exact values of previous week:
# top score r_2: 0.402915094814
# top score explained variance: 0.402915094814
# best score rmse: 0.554700196225
#
# Top Scoring Variables:
# unable to fetch coefs, trying importance...
# Total feature coefs: (322,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4295
# -> 4296         mgr = BlockManager(blocks, axes)
#    4297         mgr._consolidate_inplace()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2794         if do_integrity_check:
# -> 2795             self._verify_integrity()
#    2796
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _verify_integrity(self)
#    3005             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3006                 construction_error(tot_items, block.shape[1:], self.axes)
#    3007         if len(self.items) != tot_items:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4279     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4280         passed, implied))
#    4281
#
# ValueError: Shape of passed values is (1, 322), indices imply (1, 321)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-644a1ff5509f> in get_coefs(X_train, y_train, model)
#      24     try: #first try making the dataframe out of the X_columns
# ---> 25         coefframe = pd.DataFrame(coefs, columns=['All Variables'], index=X_train.columns)
#      26     except: #if that didn't work but it is more than one, it may be from a neural net.
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     305                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 306                                          copy=copy)
#     307         elif isinstance(data, (list, types.GeneratorType)):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     482
# --> 483         return create_block_manager_from_blocks([values], [columns, index])
#     484
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4302         tot_items = sum(b.shape[0] for b in blocks)
# -> 4303         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4304
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4279     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4280         passed, implied))
#    4281
#
# ValueError: Shape of passed values is (1, 322), indices imply (1, 321)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4293                 blocks = [make_block(values=blocks[0],
# -> 4294                                      placement=slice(0, len(axes[0])))]
#    4295
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2718
# -> 2719     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2720
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#     114                              'implies %d' % (len(self.values),
# --> 115                                              len(self.mgr_locs)))
#     116
#
# ValueError: Wrong number of items passed 1, placement implies 321
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-402da3c10c55> in <module>()
#       6
#       7 #extract and plot feature coefs
# ----> 8 coefframe = get_coefs(X_train, y_train, model)
#       9 interpret_coefs(coefs,X_train,top.index)
#      10
#
# <ipython-input-15-644a1ff5509f> in get_coefs(X_train, y_train, model)
#      33         #print(layerlst)
#      34             #make a dataframe with the list of layers as the index
# ---> 35         coefframe = pd.DataFrame(coefs, index=layerlst, columns=X_train.columns)
#      36         coefframe = coefframe.transpose()
#      37
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     304             else:
#     305                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 306                                          copy=copy)
#     307         elif isinstance(data, (list, types.GeneratorType)):
#     308             if isinstance(data, types.GeneratorType):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     481             values = maybe_infer_to_datetimelike(values)
#     482
# --> 483         return create_block_manager_from_blocks([values], [columns, index])
#     484
#     485     @property
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4301         blocks = [getattr(b, 'values', b) for b in blocks]
#    4302         tot_items = sum(b.shape[0] for b in blocks)
# -> 4303         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4304
#    4305
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4278         raise ValueError("Empty data passed with indices specified.")
#    4279     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4280         passed, implied))
#    4281
#    4282
#
# ValueError: Shape of passed values is (1, 322), indices imply (321, 322)

# %% [markdown]
# The results of the tuned model are clearly better than the un-tuned model. While the top score has not improved significantly, far more variables approach the highest scoring variable.
#
# Next we will tune MLPRegressor

# %%
#get parameter set from MLPRegressor
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(random_state=56)
model.get_params(deep=True)
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (100,),
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_iter': 200,
#  'momentum': 0.9,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': 56,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
#Tune MLPRegressor (neural net regressor)
model = MLPRegressor(random_state=56, verbose=True)    


MLP_params = {#'activation': ['identity', 'logistic', 'tanh', 'relu'],
     'alpha': np.linspace(0.00000001,.2,100),
     'beta_1': np.linspace(0.2,.6,100),
     'beta_2': np.linspace(0.2,.4,100),
     #'early_stopping': [True,False],
     'epsilon':np.linspace(0.7,.9,100),
     'hidden_layer_sizes': [(100,)],# (50,50,), (25,25,25,25,), (12,12,12,12,12,12,12,)],
     'learning_rate': ['adaptive'],
     #'learning_rate_init': np.linspace(0.00000001,10,100),
     'max_iter': range(50,60,1),
     #'momentum': np.linspace(0.00000001,1,100),
     'nesterovs_momentum': [True,False],
     'power_t': np.linspace(0.00000001,.999999,100),
     #'shuffle': [True,False],
     'solver': ['lbfgs'],
     'tol':  np.linspace(0.00000001,.999999,100)}
     #'validation_fraction':  np.linspace(0.00000001,1,100),
     #'warm_start': [False]}

MLP_best_params, MLP_best_score, MLP_results = random_search(MLP_params, model, 100)
print('\nbest parameters',MLP_best_params)
print('best score',MLP_best_score)
#Next try plotting parameters next to resulting scores
# Out:
# best parameters {'tol': 0.090909009090909071, 'solver': 'lbfgs', 'power_t': 0.17171700828282827, 'nesterovs_momentum': False, 'max_iter': 54, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (100,), 'epsilon': 0.74848484848484842, 'beta_2': 0.30505050505050507, 'beta_1': 0.37373737373737376, 'alpha': 0.056565663737373741}
# best score -0.21752211189

# %%
plot_params(MLP_params, MLP_results)
# Out:
# plotting 11 params...

# %%
model = MLPRegressor(random_state=56)# **MLP_best_params)
    
print("Finding Variables...")
scores, top = find_var(X_week, y_week, model, n_true=20, verbose=2, s_plot=0, n_plot=3)

#extract and plot feature coefs - this is not currently working for Neural Nets
#coefs = get_coefs(X_train, y_train, model)
#coefframe = interpret_coefs(coefs,X_train,top.index)

    #print top 10 scores that beat control
top[:10]
# Out:
# Finding Variables...
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/nhorning/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# top score r_2: 0.4167373382475844
# top score explained variance: 0.418823638604
# best score rmse: 0.8858962835
#
# control test - forcast using exact values of previous week:
# top score r_2: 0.402915094814
# top score explained variance: 0.402915094814
# best score rmse: 0.554700196225
#
# Top Scoring Variables:
#                                                       scores  \
#                                                          r_2
# Weapons_improvised explosive device (t)             0.259491
# Actor 1 - Youth/non-youth_na(t)                     0.250713
# Actor 2 - Target_group of civilians (t)              0.22342
# Event Form - Primary_violent - symbolic violenc... -0.062445
# Actor 2 - Target_private sector - private compa...    -0.138
# Cause - Primary_political - other political iss... -0.159849
# Actor 1 - Affiliation_political organization/po... -0.248218
# Event Form - Primary_violent - vandalism(t)        -0.264918
# Actor 2 - Affiliation_citizen/individuals(t)       -0.457045
# Female injured(t)                                  -0.493085
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                      0.259584
# Actor 1 - Youth/non-youth_na(t)                               0.25143
# Actor 2 - Target_group of civilians (t)                      0.224532
# Event Form - Primary_violent - symbolic violenc...         -0.0576949
# Actor 2 - Target_private sector - private compa...          -0.112617
# Cause - Primary_political - other political iss...          -0.152422
# Actor 1 - Affiliation_political organization/po...           -0.24295
# Event Form - Primary_violent - vandalism(t)                 -0.229985
# Actor 2 - Affiliation_citizen/individuals(t)                -0.456146
# Female injured(t)                                           -0.470559
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                            11.1529
# Actor 1 - Youth/non-youth_na(t)                                     4.1158
# Actor 2 - Target_group of civilians (t)                            6.88043
# Event Form - Primary_violent - symbolic violenc...                 7.74646
# Actor 2 - Target_private sector - private compa...                 2.55702
# Cause - Primary_political - other political iss...                 4.85728
# Actor 1 - Affiliation_political organization/po...                 8.65194
# Event Form - Primary_violent - vandalism(t)                        3.13068
# Actor 2 - Affiliation_citizen/individuals(t)                        1.2199
# Female injured(t)                                                  3.08374
#
#                                                    control_scores  \
#                                                               r_2
# Weapons_improvised explosive device (t)                 0.0283659
# Actor 1 - Youth/non-youth_na(t)                         0.0124281
# Actor 2 - Target_group of civilians (t)                 -0.467861
# Event Form - Primary_violent - symbolic violenc...      -0.438543
# Actor 2 - Target_private sector - private compa...      -0.727113
# Cause - Primary_political - other political iss...      -0.469136
# Actor 1 - Affiliation_political organization/po...      -0.496253
# Event Form - Primary_violent - vandalism(t)             -0.543737
# Actor 2 - Affiliation_citizen/individuals(t)            -0.977007
# Female injured(t)                                       -0.721079
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                     0.0283659
# Actor 1 - Youth/non-youth_na(t)                             0.0124281
# Actor 2 - Target_group of civilians (t)                     -0.467861
# Event Form - Primary_violent - symbolic violenc...          -0.438543
# Actor 2 - Target_private sector - private compa...          -0.727113
# Cause - Primary_political - other political iss...          -0.469063
# Actor 1 - Affiliation_political organization/po...          -0.496247
# Event Form - Primary_violent - vandalism(t)                  -0.54369
# Actor 2 - Affiliation_citizen/individuals(t)                -0.977007
# Female injured(t)                                           -0.721021
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                            12.7754
# Actor 1 - Youth/non-youth_na(t)                                    4.72514
# Actor 2 - Target_group of civilians (t)                            9.45943
# Event Form - Primary_violent - symbolic violenc...                 9.01388
# Actor 2 - Target_private sector - private compa...                 3.15009
# Cause - Primary_political - other political iss...                 5.46668
# Actor 1 - Affiliation_political organization/po...                 9.47263
# Event Form - Primary_violent - vandalism(t)                        3.45855
# Actor 2 - Affiliation_citizen/individuals(t)                         1.421
# Female injured(t)                                                  3.31082
#
#                                                       cv_mean  \
#                                                           r_2
# Weapons_improvised explosive device (t)             -3.990413
# Actor 1 - Youth/non-youth_na(t)                     -0.344386
# Actor 2 - Target_group of civilians (t)             -0.296988
# Event Form - Primary_violent - symbolic violenc...  -1.298241
# Actor 2 - Target_private sector - private compa...  -2.525407
# Cause - Primary_political - other political iss...  -1.387580
# Actor 1 - Affiliation_political organization/po... -10.250258
# Event Form - Primary_violent - vandalism(t)         -2.896420
# Actor 2 - Affiliation_citizen/individuals(t)        -0.515067
# Female injured(t)                                   -0.468951
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                     -1.731548
# Actor 1 - Youth/non-youth_na(t)                             -0.144359
# Actor 2 - Target_group of civilians (t)                     -0.039722
# Event Form - Primary_violent - symbolic violenc...          -1.016048
# Actor 2 - Target_private sector - private compa...          -1.386831
# Cause - Primary_political - other political iss...          -0.318214
# Actor 1 - Affiliation_political organization/po...          -6.477039
# Event Form - Primary_violent - vandalism(t)                 -1.972779
# Actor 2 - Affiliation_citizen/individuals(t)                -0.459846
# Female injured(t)                                           -0.436597
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                           8.064327
# Actor 1 - Youth/non-youth_na(t)                                   3.763374
# Actor 2 - Target_group of civilians (t)                           5.708493
# Event Form - Primary_violent - symbolic violenc...                5.505528
# Actor 2 - Target_private sector - private compa...                2.256844
# Cause - Primary_political - other political iss...                4.702236
# Actor 1 - Affiliation_political organization/po...                3.221521
# Event Form - Primary_violent - vandalism(t)                       2.168107
# Actor 2 - Affiliation_citizen/individuals(t)                      1.041133
# Female injured(t)                                                 2.981023
#
#                                                            Q1  \
#                                                           r_2
# Weapons_improvised explosive device (t)             -0.054276
# Actor 1 - Youth/non-youth_na(t)                     -0.185027
# Actor 2 - Target_group of civilians (t)             -0.202903
# Event Form - Primary_violent - symbolic violenc...  -0.029394
# Actor 2 - Target_private sector - private compa...  -5.561058
# Cause - Primary_political - other political iss...  -0.661759
# Actor 1 - Affiliation_political organization/po... -13.266185
# Event Form - Primary_violent - vandalism(t)         -6.241733
# Actor 2 - Affiliation_citizen/individuals(t)        -0.274303
# Female injured(t)                                   -0.293618
#
#                                                              ...            \
#                                                              ...
# Weapons_improvised explosive device (t)                      ...
# Actor 1 - Youth/non-youth_na(t)                              ...
# Actor 2 - Target_group of civilians (t)                      ...
# Event Form - Primary_violent - symbolic violenc...           ...
# Actor 2 - Target_private sector - private compa...           ...
# Cause - Primary_political - other political iss...           ...
# Actor 1 - Affiliation_political organization/po...           ...
# Event Form - Primary_violent - vandalism(t)                  ...
# Actor 2 - Affiliation_citizen/individuals(t)                 ...
# Female injured(t)                                            ...
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                          14.458556
# Actor 1 - Youth/non-youth_na(t)                                   5.775426
# Actor 2 - Target_group of civilians (t)                          13.074575
# Event Form - Primary_violent - symbolic violenc...               11.202386
# Actor 2 - Target_private sector - private compa...                2.596437
# Cause - Primary_political - other political iss...                2.315886
# Actor 1 - Affiliation_political organization/po...                5.960101
# Event Form - Primary_violent - vandalism(t)                       2.591661
# Actor 2 - Affiliation_citizen/individuals(t)                      1.646535
# Female injured(t)                                                 3.282165
#
#                                                            Q2  \
#                                                           r_2
# Weapons_improvised explosive device (t)              0.680441
# Actor 1 - Youth/non-youth_na(t)                      0.709067
# Actor 2 - Target_group of civilians (t)              0.669988
# Event Form - Primary_violent - symbolic violenc...   0.480461
# Actor 2 - Target_private sector - private compa...   0.133264
# Cause - Primary_political - other political iss...  -0.113035
# Actor 1 - Affiliation_political organization/po... -23.431827
# Event Form - Primary_violent - vandalism(t)         -2.789438
# Actor 2 - Affiliation_citizen/individuals(t)        -0.712000
# Female injured(t)                                   -0.989605
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                      0.684363
# Actor 1 - Youth/non-youth_na(t)                              0.714379
# Actor 2 - Target_group of civilians (t)                      0.670697
# Event Form - Primary_violent - symbolic violenc...           0.486904
# Actor 2 - Target_private sector - private compa...           0.147494
# Cause - Primary_political - other political iss...          -0.083583
# Actor 1 - Affiliation_political organization/po...         -16.257808
# Event Form - Primary_violent - vandalism(t)                 -2.701857
# Actor 2 - Affiliation_citizen/individuals(t)                -0.680347
# Female injured(t)                                           -0.983277
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                          12.738724
# Actor 1 - Youth/non-youth_na(t)                                   3.784908
# Actor 2 - Target_group of civilians (t)                           6.771099
# Event Form - Primary_violent - symbolic violenc...                7.950287
# Actor 2 - Target_private sector - private compa...                2.797223
# Cause - Primary_political - other political iss...                7.185467
# Actor 1 - Affiliation_political organization/po...                5.437142
# Event Form - Primary_violent - vandalism(t)                       3.007870
# Actor 2 - Affiliation_citizen/individuals(t)                      0.913564
# Female injured(t)                                                 3.074187
#
#                                                           Q3  \
#                                                          r_2
# Weapons_improvised explosive device (t)             0.030399
# Actor 1 - Youth/non-youth_na(t)                    -0.818657
# Actor 2 - Target_group of civilians (t)             0.066648
# Event Form - Primary_violent - symbolic violenc... -0.314865
# Actor 2 - Target_private sector - private compa... -0.900528
# Cause - Primary_political - other political iss... -0.194507
# Actor 1 - Affiliation_political organization/po... -3.904547
# Event Form - Primary_violent - vandalism(t)        -1.705569
# Actor 2 - Affiliation_citizen/individuals(t)       -1.277141
# Female injured(t)                                  -0.272665
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                      0.047736
# Actor 1 - Youth/non-youth_na(t)                             -0.677389
# Actor 2 - Target_group of civilians (t)                      0.074106
# Event Form - Primary_violent - symbolic violenc...          -0.310439
# Actor 2 - Target_private sector - private compa...          -0.895606
# Cause - Primary_political - other political iss...          -0.179608
# Actor 1 - Affiliation_political organization/po...          -3.347400
# Event Form - Primary_violent - vandalism(t)                 -1.343954
# Actor 2 - Affiliation_citizen/individuals(t)                -1.132675
# Female injured(t)                                           -0.183641
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                           3.381065
# Actor 1 - Youth/non-youth_na(t)                                   4.210387
# Actor 2 - Target_group of civilians (t)                           2.273933
# Event Form - Primary_violent - symbolic violenc...                1.863127
# Actor 2 - Target_private sector - private compa...                2.462252
# Cause - Primary_political - other political iss...                6.387830
# Actor 1 - Affiliation_political organization/po...                0.885848
# Event Form - Primary_violent - vandalism(t)                       1.471209
# Actor 2 - Affiliation_citizen/individuals(t)                      1.195369
# Female injured(t)                                                 2.815230
#
#                                                            Q4  \
#                                                           r_2
# Weapons_improvised explosive device (t)            -16.618217
# Actor 1 - Youth/non-youth_na(t)                     -1.082926
# Actor 2 - Target_group of civilians (t)             -1.721683
# Event Form - Primary_violent - symbolic violenc...  -5.329166
# Actor 2 - Target_private sector - private compa...  -3.773305
# Cause - Primary_political - other political iss...  -4.581019
# Actor 1 - Affiliation_political organization/po...  -0.398472
# Event Form - Primary_violent - vandalism(t)         -0.848942
# Actor 2 - Affiliation_citizen/individuals(t)         0.203175
# Female injured(t)                                   -0.319916
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                     -7.609095
# Actor 1 - Youth/non-youth_na(t)                             -0.440077
# Actor 2 - Target_group of civilians (t)                     -0.701786
# Event Form - Primary_violent - symbolic violenc...          -4.212690
# Actor 2 - Target_private sector - private compa...          -2.302945
# Cause - Primary_political - other political iss...          -0.496665
# Actor 1 - Affiliation_political organization/po...          -0.352135
# Event Form - Primary_violent - vandalism(t)                 -0.848596
# Actor 2 - Affiliation_citizen/individuals(t)                 0.238981
# Female injured(t)                                           -0.313628
#
#
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                           1.678962
# Actor 1 - Youth/non-youth_na(t)                                   1.282775
# Actor 2 - Target_group of civilians (t)                           0.714364
# Event Form - Primary_violent - symbolic violenc...                1.006313
# Actor 2 - Target_private sector - private compa...                1.171463
# Cause - Primary_political - other political iss...                2.919761
# Actor 1 - Affiliation_political organization/po...                0.602995
# Event Form - Primary_violent - vandalism(t)                       1.601689
# Actor 2 - Affiliation_citizen/individuals(t)                      0.409064
# Female injured(t)                                                 2.752512
#
# [10 rows x 21 columns]

# %% [markdown]
# Using the best tuned MLPRegressor does not result in many high scoring variables. However, an extremely interesting result is it seems to learn how to predict 3 of them very accurately in advance of a major spike. This could be a promising future application for machine learning with Nepal Monitor.

# %%
#Plot top 3 variables from MLPRegressor for presentation

plt.rcParams.update({'font.size': 16})
top.iloc[:3,:2].plot(kind='barh')
plt.legend(bbox_to_anchor=(1,1.2))
plt.show()

#top.iloc[:3,1].plot(kind='barh', color=catpal[2])
#plt.legend(bbox_to_anchor=(1,1.1))
#plt.show()

top.iloc[:3,3:5].plot(kind='barh')
plt.legend(bbox_to_anchor=(1,1.2))
plt.show()

#top.iloc[:3,5].plot(kind='barh', color=catpal[2])
#plt.legend(bbox_to_anchor=(1,1.1))
#plt.show()

# %%
from sklearn.linear_model import Lasso

model.get_params(deep=True)
# Out:
# {'activation': 'relu',
#  'alpha': 0.056565663737373741,
#  'batch_size': 'auto',
#  'beta_1': 0.37373737373737376,
#  'beta_2': 0.30505050505050507,
#  'early_stopping': False,
#  'epsilon': 0.74848484848484842,
#  'hidden_layer_sizes': (100,),
#  'learning_rate': 'adaptive',
#  'learning_rate_init': 0.001,
#  'max_iter': 54,
#  'momentum': 0.9,
#  'nesterovs_momentum': False,
#  'power_t': 0.17171700828282827,
#  'random_state': 56,
#  'shuffle': True,
#  'solver': 'lbfgs',
#  'tol': 0.090909009090909071,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
#Tune Lasso
model = Lasso(random_state=56)

Lasso_params = {#'alpha': [1],
             #'copy_X': True,
             'fit_intercept': [False],
             #'max_iter': np.linspace(0,2000,100),
             'normalize': [True,False],
             'positive': [True],
             'precompute': [True,False],
             #'random_state': 56,
             'selection': ['random'],
             'tol': np.linspace(0.00000001,.2,100)}
 
Lasso_best_params, Lasso_best_score, Lasso_results = random_search(Lasso_params, model, 100)
print('\nbest parameters',Lasso_best_params)
print('best score',Lasso_best_score)
#Next try plotting parameters next to resulting scores
# Out:
# best parameters {'tol': 0.15353535585858585, 'selection': 'random', 'precompute': True, 'positive': True, 'normalize': False, 'fit_intercept': False}
# best score -0.329743506964

# %%
plot_params(Lasso_params, Lasso_results)
# Out:
# plotting 6 params...

# %% [markdown]
# Lasso has so far been the 3rd best model in the comparative evaluation. Optimizing it with Random_Search found a few parameters that performed better than default. The remaining variation in scores appears to be mostly a function of tolerance.

# %%
model = Lasso(random_state=56, **Lasso_best_params)
    
print("Finding Variables...")
scores, top = find_var(X_week, y_week, model, n_true=20, verbose=1, s_plot=0, n_plot=3)

#extract and plot feature coefs - this is not currently working for Neural Nets
#coefs = get_coefs(X_train, y_train, model)
#coefframe = interpret_coefs(coefs,X_train,top.index)

    #print top 10 scores that beat control
top[:10]
# Out:
# Finding Variables...
#
# Top Scoring Variables:
#                                                         scores  \
#                                                            r_2
# Weapons_improvised explosive device (t)               0.301857
# Actor 1 - Affiliation_unclear(t)                      0.199967
# Actor 1 - Youth/non-youth_na(t)                       0.120102
# Actor 2 - Target_group of civilians (t)              0.0785848
# Actor 2 - Target_civil state institutions - loc...    0.043026
# Event Form - Primary_violent - symbolic violenc...   0.0046992
# Cause - Primary_political - other political iss... -0.00891768
# Total injured(t)                                    -0.0141966
# Event Form - Secondary_violent - vandalism(t)       -0.0216568
# Event Form - Primary_violent - unclear(t)           -0.0255876
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                      0.305085
# Actor 1 - Affiliation_unclear(t)                              0.20152
# Actor 1 - Youth/non-youth_na(t)                              0.131982
# Actor 2 - Target_group of civilians (t)                     0.0868149
# Actor 2 - Target_civil state institutions - loc...           0.086983
# Event Form - Primary_violent - symbolic violenc...          0.0117009
# Cause - Primary_political - other political iss...        -0.00814053
# Total injured(t)                                          -0.00740055
# Event Form - Secondary_violent - vandalism(t)              -0.0115116
# Event Form - Primary_violent - unclear(t)                   0.0168268
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                            10.8292
# Actor 1 - Affiliation_unclear(t)                                   12.2165
# Actor 1 - Youth/non-youth_na(t)                                    4.46012
# Actor 2 - Target_group of civilians (t)                            7.49463
# Actor 2 - Target_civil state institutions - loc...                 3.67297
# Event Form - Primary_violent - symbolic violenc...                 7.49769
# Cause - Primary_political - other political iss...                 4.53023
# Total injured(t)                                                   22.7815
# Event Form - Secondary_violent - vandalism(t)                     0.684203
# Event Form - Primary_violent - unclear(t)                         0.555983
#
#                                                    control_scores  \
#                                                               r_2
# Weapons_improvised explosive device (t)                 0.0283659
# Actor 1 - Affiliation_unclear(t)                        0.0916371
# Actor 1 - Youth/non-youth_na(t)                         0.0124281
# Actor 2 - Target_group of civilians (t)                 -0.467861
# Actor 2 - Target_civil state institutions - loc...      -0.102232
# Event Form - Primary_violent - symbolic violenc...      -0.438543
# Cause - Primary_political - other political iss...      -0.469136
# Total injured(t)                                        -0.325367
# Event Form - Secondary_violent - vandalism(t)            -0.88862
# Event Form - Primary_violent - unclear(t)               -0.722699
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                     0.0283659
# Actor 1 - Affiliation_unclear(t)                            0.0916376
# Actor 1 - Youth/non-youth_na(t)                             0.0124281
# Actor 2 - Target_group of civilians (t)                     -0.467861
# Actor 2 - Target_civil state institutions - loc...          -0.102128
# Event Form - Primary_violent - symbolic violenc...          -0.438543
# Cause - Primary_political - other political iss...          -0.469063
# Total injured(t)                                            -0.325295
# Event Form - Secondary_violent - vandalism(t)                -0.88862
# Event Form - Primary_violent - unclear(t)                   -0.722699
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                            12.7754
# Actor 1 - Affiliation_unclear(t)                                   13.0174
# Actor 1 - Youth/non-youth_na(t)                                    4.72514
# Actor 2 - Target_group of civilians (t)                            9.45943
# Actor 2 - Target_civil state institutions - loc...                 3.94189
# Event Form - Primary_violent - symbolic violenc...                 9.01388
# Cause - Primary_political - other political iss...                 5.46668
# Total injured(t)                                                   26.0429
# Event Form - Secondary_violent - vandalism(t)                     0.930261
# Event Form - Primary_violent - unclear(t)                         0.720577
#
#                                                      cv_mean  \
#                                                          r_2
# Weapons_improvised explosive device (t)            -6.123928
# Actor 1 - Affiliation_unclear(t)                   -0.873458
# Actor 1 - Youth/non-youth_na(t)                    -0.039189
# Actor 2 - Target_group of civilians (t)            -1.933515
# Actor 2 - Target_civil state institutions - loc... -0.742700
# Event Form - Primary_violent - symbolic violenc... -3.186352
# Cause - Primary_political - other political iss... -0.605750
# Total injured(t)                                   -0.189337
# Event Form - Secondary_violent - vandalism(t)      -0.260812
# Event Form - Primary_violent - unclear(t)          -0.208481
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                     -4.520812
# Actor 1 - Affiliation_unclear(t)                            -0.712567
# Actor 1 - Youth/non-youth_na(t)                              0.068433
# Actor 2 - Target_group of civilians (t)                     -1.397358
# Actor 2 - Target_civil state institutions - loc...          -0.065196
# Event Form - Primary_violent - symbolic violenc...          -2.300050
# Cause - Primary_political - other political iss...          -0.065613
# Total injured(t)                                            -0.138221
# Event Form - Secondary_violent - vandalism(t)               -0.080236
# Event Form - Primary_violent - unclear(t)                   -0.104936
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                           8.982019
# Actor 1 - Affiliation_unclear(t)                                  9.594289
# Actor 1 - Youth/non-youth_na(t)                                   3.873605
# Actor 2 - Target_group of civilians (t)                           6.782247
# Actor 2 - Target_civil state institutions - loc...                3.220792
# Event Form - Primary_violent - symbolic violenc...                6.235372
# Cause - Primary_political - other political iss...                4.305749
# Total injured(t)                                                 15.877552
# Event Form - Secondary_violent - vandalism(t)                     0.569303
# Event Form - Primary_violent - unclear(t)                         0.382751
#
#                                                           Q1  \
#                                                          r_2
# Weapons_improvised explosive device (t)            -0.083334
# Actor 1 - Affiliation_unclear(t)                   -0.083306
# Actor 1 - Youth/non-youth_na(t)                     0.086965
# Actor 2 - Target_group of civilians (t)            -0.193279
# Actor 2 - Target_civil state institutions - loc...  0.166169
# Event Form - Primary_violent - symbolic violenc... -0.091143
# Cause - Primary_political - other political iss... -0.149167
# Total injured(t)                                   -0.051957
# Event Form - Secondary_violent - vandalism(t)      -0.120079
# Event Form - Primary_violent - unclear(t)           0.039356
#
#                                                              ...            \
#                                                              ...
# Weapons_improvised explosive device (t)                      ...
# Actor 1 - Affiliation_unclear(t)                             ...
# Actor 1 - Youth/non-youth_na(t)                              ...
# Actor 2 - Target_group of civilians (t)                      ...
# Actor 2 - Target_civil state institutions - loc...           ...
# Event Form - Primary_violent - symbolic violenc...           ...
# Cause - Primary_political - other political iss...           ...
# Total injured(t)                                             ...
# Event Form - Secondary_violent - vandalism(t)                ...
# Event Form - Primary_violent - unclear(t)                    ...
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                          14.656451
# Actor 1 - Affiliation_unclear(t)                                 15.127645
# Actor 1 - Youth/non-youth_na(t)                                   5.069484
# Actor 2 - Target_group of civilians (t)                          13.022167
# Actor 2 - Target_civil state institutions - loc...                2.481921
# Event Form - Primary_violent - symbolic violenc...               11.533484
# Cause - Primary_political - other political iss...                1.925860
# Total injured(t)                                                 17.606854
# Event Form - Secondary_violent - vandalism(t)                     0.777716
# Event Form - Primary_violent - unclear(t)                         0.449149
#
#                                                           Q2  \
#                                                          r_2
# Weapons_improvised explosive device (t)             0.549399
# Actor 1 - Affiliation_unclear(t)                    0.461074
# Actor 1 - Youth/non-youth_na(t)                     0.352762
# Actor 2 - Target_group of civilians (t)             0.283971
# Actor 2 - Target_civil state institutions - loc... -0.318411
# Event Form - Primary_violent - symbolic violenc...  0.213127
# Cause - Primary_political - other political iss... -0.070222
# Total injured(t)                                   -0.251814
# Event Form - Secondary_violent - vandalism(t)      -0.276910
# Event Form - Primary_violent - unclear(t)          -0.538562
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                      0.557381
# Actor 1 - Affiliation_unclear(t)                             0.468825
# Actor 1 - Youth/non-youth_na(t)                              0.377422
# Actor 2 - Target_group of civilians (t)                      0.304309
# Actor 2 - Target_civil state institutions - loc...          -0.315454
# Event Form - Primary_violent - symbolic violenc...           0.223600
# Cause - Primary_political - other political iss...          -0.012046
# Total injured(t)                                            -0.246674
# Event Form - Secondary_violent - vandalism(t)               -0.203585
# Event Form - Primary_violent - unclear(t)                   -0.412097
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                          15.126794
# Actor 1 - Affiliation_unclear(t)                                 16.875880
# Actor 1 - Youth/non-youth_na(t)                                   5.645350
# Actor 2 - Target_group of civilians (t)                           9.973772
# Actor 2 - Target_civil state institutions - loc...                4.179193
# Event Form - Primary_violent - symbolic violenc...                9.784218
# Cause - Primary_political - other political iss...                7.045916
# Total injured(t)                                                 18.835184
# Event Form - Secondary_violent - vandalism(t)                     0.749560
# Event Form - Primary_violent - unclear(t)                         0.537104
#
#                                                           Q3  \
#                                                          r_2
# Weapons_improvised explosive device (t)            -0.442645
# Actor 1 - Affiliation_unclear(t)                   -2.606533
# Actor 1 - Youth/non-youth_na(t)                    -0.529846
# Actor 2 - Target_group of civilians (t)            -0.501114
# Actor 2 - Target_civil state institutions - loc... -0.496724
# Event Form - Primary_violent - symbolic violenc... -0.796228
# Cause - Primary_political - other political iss... -0.077137
# Total injured(t)                                   -0.196069
# Event Form - Secondary_violent - vandalism(t)      -0.087096
# Event Form - Primary_violent - unclear(t)          -0.334718
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                     -0.414603
# Actor 1 - Affiliation_unclear(t)                            -1.980751
# Actor 1 - Youth/non-youth_na(t)                             -0.338481
# Actor 2 - Target_group of civilians (t)                     -0.305093
# Actor 2 - Target_civil state institutions - loc...          -0.433783
# Event Form - Primary_violent - symbolic violenc...          -0.350288
# Cause - Primary_political - other political iss...          -0.051910
# Total injured(t)                                            -0.018486
# Event Form - Secondary_violent - vandalism(t)                0.139551
# Event Form - Primary_violent - unclear(t)                   -0.087492
#
#                                                                             \
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                           4.124171
# Actor 1 - Affiliation_unclear(t)                                  4.266612
# Actor 1 - Youth/non-youth_na(t)                                   3.861629
# Actor 2 - Target_group of civilians (t)                           2.883777
# Actor 2 - Target_civil state institutions - loc...                3.952948
# Event Form - Primary_violent - symbolic violenc...                2.177623
# Cause - Primary_political - other political iss...                6.065887
# Total injured(t)                                                 17.231402
# Event Form - Secondary_violent - vandalism(t)                     0.477797
# Event Form - Primary_violent - unclear(t)                         0.412525
#
#                                                            Q4  \
#                                                           r_2
# Weapons_improvised explosive device (t)            -24.519131
# Actor 1 - Affiliation_unclear(t)                    -1.265067
# Actor 1 - Youth/non-youth_na(t)                     -0.066638
# Actor 2 - Target_group of civilians (t)             -7.323641
# Actor 2 - Target_civil state institutions - loc...  -2.321835
# Event Form - Primary_violent - symbolic violenc... -12.071164
# Cause - Primary_political - other political iss...  -2.126472
# Total injured(t)                                    -0.257507
# Event Form - Secondary_violent - vandalism(t)       -0.559162
# Event Form - Primary_violent - unclear(t)            0.000000
#
#                                                                        \
#                                                    explained_variance
# Weapons_improvised explosive device (t)                    -18.143086
# Actor 1 - Affiliation_unclear(t)                            -1.257926
# Actor 1 - Youth/non-youth_na(t)                              0.146183
# Actor 2 - Target_group of civilians (t)                     -5.395827
# Actor 2 - Target_civil state institutions - loc...           0.320507
# Event Form - Primary_violent - symbolic violenc...          -8.982548
# Cause - Primary_political - other political iss...          -0.093943
# Total injured(t)                                            -0.257496
# Event Form - Secondary_violent - vandalism(t)               -0.137468
# Event Form - Primary_violent - unclear(t)                    0.000000
#
#
#                                                    root_mean_squared_error
# Weapons_improvised explosive device (t)                           2.020659
# Actor 1 - Affiliation_unclear(t)                                  2.107020
# Actor 1 - Youth/non-youth_na(t)                                   0.917956
# Actor 2 - Target_group of civilians (t)                           1.249273
# Actor 2 - Target_civil state institutions - loc...                2.269106
# Event Form - Primary_violent - symbolic violenc...                1.446163
# Cause - Primary_political - other political iss...                2.185334
# Total injured(t)                                                  9.836768
# Event Form - Secondary_violent - vandalism(t)                     0.272140
# Event Form - Primary_violent - unclear(t)                         0.132228
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Comparatively Evaluate Predictive Models
# The function below was used to iteratively compare and select the best models. Models were commented out as they were eliminated for various reasons.

# %%
import warnings
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import HuberRegressor
from sklearn.linear_model import Lars
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import MultiTaskLassoCV
from sklearn.linear_model import MultiTaskElasticNetCV
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import Perceptron
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import TheilSenRegressor



def search_models(modellist, catlist, verbose=False, random_state=False):
    '''function to comparatively evaluate a list of models'''
    #create a dataframe for the scores
    scoresdf = pd.DataFrame(index=catlist)
    
    #turn warnings off to avoid clutter
    warnings.filterwarnings("ignore")
    
    #loop through the models and evaluate them
    for model in modellist:
        
        #get the name of the model
        modelstring = str(model).split('(')[0]
        
        #print the name of the model
        print('\n{}:'.format(modelstring))
        
        #prune X variables according to top coefs?
        topcoefs = coefframe.loc[coefframe.iloc[:,0] > 0.01]
        
        #evaluate model
        print('Evaluating model...')
        _, model_scoresdf = find_var(X_week, y_week, model, n_true=20, verbose=verbose, random_state=random_state)
        
        #print the top 3 scores in explained variance
        print('Top 3 scores:\n',model_scoresdf[('scores','explained_variance')].sort_values(ascending=False)[:3])
        
        #if we haven't added anything to scores df yet, grab the control scores and add them
        if scoresdf.shape[1] < 3:
            scoresdf = pd.concat([scoresdf, model_scoresdf.iloc[:,3:6]], axis=1)
        
        #add the scores from the model to the dataframe
        scoresdf = pd.concat([scoresdf, model_scoresdf.iloc[:,:3]], axis=1)
        
        #label first section of df < debug later
        new_cols = scoresdf.columns.tolist()
        for x in range(3):
            i = len(new_cols)- 1 - x
            new_cols[i] = (modelstring, new_cols[i][1])
            #print('appended!', modelstring, 'to', new_cols[x][0])
        scoresdf.columns = new_cols
        print('appended', modelstring, 'to columns')
                
    print('Bing!')
    return scoresdf

if __name__ == '__main__': #protect windows from parallel processes(if you run windows)
    random_state=56
    modellist=[#LinearRegression(),
               RandomForestRegressor(random_state=random_state,**best_params),
               MLPRegressor(random_state=random_state,**MLP_best_params),
               #BayesianRidge(),
               #ARDRegression(),# <throws a big error
               
               ElasticNet(random_state=random_state),
               #ElasticNetCV(random_state=random_state), < save automatic Cv for holdout sets
               #HuberRegressor(),
               #Lars(random_state=random_state), < tiny results
               Lasso(random_state=random_state, **Lasso_best_params)] #add after fixing function
               #MultiTaskLassoCV(random_state=random_state),<way too slow
               #PassiveAggressiveRegressor(random_state=random_state),
               #Perceptron(random_state=random_state),
               #TheilSenRegressor(random_state=random_state)]
               #RidgeCV()]
    
    scoresdf = search_models(modellist, y_week.columns, random_state=random_state)
    scoresdf.head()
# Out:
# RandomForestRegressor:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a5fbb165d490> in <module>()
#      85                #RidgeCV()]
#      86
# ---> 87     scoresdf = search_models(modellist, y_week.columns, random_state=random_state)
#      88     scoresdf.head()
#
# <ipython-input-38-a5fbb165d490> in search_models(modellist, catlist, verbose, random_state)
#      38
#      39         #prune X variables according to top coefs?
# ---> 40         topcoefs = coefframe.loc[coefframe.iloc[:,0] > 0.01]
#      41
#      42         #evaluate model
#
# NameError: name 'coefframe' is not defined

# %%
scoresdf

# %%
#Plot the best scores of various regressors - change to top 5? seperately?
colr=0
expv = scoresdf.iloc[:,0::3]#.dropna()
for col in expv.columns:
    data = expv.sort_values(col, ascending=False)[:5]
    f, ax = plt.subplots(1,1, figsize=(8,4))
    ax.set_xlim(-.0,.6)

    #plot = expv.loc[expv[col] > 0]
    #if len(expv) > 0:
    sns.barplot(x=col, y=data.index, data=data, color=catpal[colr*2], label=col[0], alpha=0.5, ax=ax, dodge=False)
    colr+=1
    #sns.barplot(y=expv.index, data=expv, alpha=0.5, ax=ax)    
    plt.xlabel(expv.columns[0][1]+' score')
    plt.ylabel('output category')
    plt.legend(bbox_to_anchor=(-0.02,0))
    plt.rcParams.update({'font.size': 20})
    plt.show()
        
#for col in scoresdf.columns[2::3]:
    #plot = scoresdf[[col]].sort_values(col).loc[scoresdf[col] < .3]
    #if len(plot) > 0:
        #sns.barplot(x=col, y=plot.index, data=plot)
        #plt.show()
expv.head()

# %%
#plot them all together - some variables missing

#plt.figure(figsize=(8,12))
expv.plot(kind='barh', figsize=(8,15), width=1, alpha=.5)
plt.legend(bbox_to_anchor=(-0.02,0))
plt.xlim(-.0,.5)
plt.show()

# %%
#an attempt to optmize by lookback range has been removed
